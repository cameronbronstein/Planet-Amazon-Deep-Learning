# %% [markdown]
# First Imports

# %%
import json
import requests

# %% [markdown]
# API Key and URL

# %%
PLANET_API_KEY = 'YOUR API KEY HERE'

# %%
# Helper function to printformatted JSON using the json module
def printer(data):
    print(json.dumps(data, indent=2))

# %% [markdown]
# Requests

# %%
URL = 'https://api.planet.com/data/v1'

session = requests.Session()

res = session.get(URL, auth = (PLANET_API_KEY, '') )

# %%
res.status_code
# Out:
# 200

# %%
res.text
# Out:
# '{"_links": {"_self": "https://api.planet.com/data/v1/", "asset-types": "https://api.planet.com/data/v1/asset-types/", "item-types": "https://api.planet.com/data/v1/item-types/", "spec": "https://api.planet.com/data/v1/spec"}}'

# %%
printer(res.json())
# Out:
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/",
#     "asset-types": "https://api.planet.com/data/v1/asset-types/",
#     "item-types": "https://api.planet.com/data/v1/item-types/",
#     "spec": "https://api.planet.com/data/v1/spec"
#   }
# }

# %%
print(res.json()["_links"]["item-types"])
# Out:
# https://api.planet.com/data/v1/item-types/

# %% [markdown]
# Statistics endpoint

# %%
stats_url = "{}/stats".format(URL)
print(stats_url)
# Out:
# https://api.planet.com/data/v1/stats

# %% [markdown]
# **Filter Criteria:**
# - Type (type) - The type of filter being used
# - Configuration (config) - The configuration for this filter
# - Field Name (field_name) - The field on which to filter

# %%
#Specify the sensors/satellites or "item types" to include in our results
item_types = ["PSScene3Band", "REOrthoTile"]

# %%
# Create filter object for all imagery captured between 2013-01-01 and present.
date_filter = {
    "type": "DateRangeFilter", # Type of filter -> Date Range
    "field_name": "acquired", # The field to filter on: "acquired" -> Date on which the "image was taken"
    "config": {
        "gte": "2013-01-01T00:00:00.000Z", # "gte" -> Greater than or equal to
    }
}

# %%
# Construct the request.
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : date_filter
}

# Send the POST request to the API stats endpoint
res = session.post(stats_url, json=request)

# Print response
printer(res.json())
# Out:
# {
#   "utc_offset": "+0h",
#   "interval": "year",
#   "buckets": [
#     {
#       "count": 3095020,
#       "start_time": "2013-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 3596278,
#       "start_time": "2014-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 8491790,
#       "start_time": "2015-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 37679317,
#       "start_time": "2016-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 174726781,
#       "start_time": "2017-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 241887318,
#       "start_time": "2018-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 12163463,
#       "start_time": "2019-01-01T00:00:00.000000Z"
#     }
#   ]
# }

# %% [markdown]
# Practice Exercise

# %%
# Fill in this filter to complete the exercise! 
date_filter2 = {
    'type': 'DateRangeFilter',
    'field_name': 'acquired',
    'config': {
        'lte': "2013-01-01T00:00:00.000Z"
    }
}

request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : date_filter
}

res = session.post(stats_url, json=request)
printer(res.json())
# Out:
# {
#   "utc_offset": "+0h",
#   "interval": "year",
#   "buckets": [
#     {
#       "count": 3095020,
#       "start_time": "2013-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 3596278,
#       "start_time": "2014-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 8491790,
#       "start_time": "2015-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 37679317,
#       "start_time": "2016-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 174726781,
#       "start_time": "2017-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 241887318,
#       "start_time": "2018-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 12163463,
#       "start_time": "2019-01-01T00:00:00.000000Z"
#     }
#   ]
# }

# %% [markdown]
# **Field Filters**
# - DateRangeFilter
# - RangeFilter
# - StringInFilter
# - PermissionFilter
# - GeometryFilter
#
# **Logical Filters**
# - NotFilter
# - AndFilter
# - OrFilter

# %% [markdown]
# **Camp Fire Dates:**
#
# Began: 2018-11-08
#
# Contained: 2018-11-25
#
# End buring: 2018-??-??

# %%
camp_fire_filter = {  
   "type":"AndFilter",
   "config":[  
      {  
         "type":"DateRangeFilter",
         "field_name":"acquired",
         "config":{  
            "gte":"2018-11-01T00:00:00Z",
            "lte":"2018-12-01T00:00:00Z"
         }
      },
      {  
         "type":"GeometryFilter",
         "field_name":"geometry",
         "config":{"type":"Polygon",
                   "coordinates": [
          [
            [
              -122.11166381835936,
              39.977120098439634
            ],
            [
              -122.0745849609375,
              39.48814483559126
            ],
            [
              -121.09268188476562,
              39.54641191968671
            ],
            [
              -121.12976074218749,
              39.985538414809746
            ],
            [
              -122.11166381835936,
              39.977120098439634
            ]
          ]
        ]
                  }
      }
    ]
}

# %%
request = {
    "item_types" : item_types,
    "interval" : "day",
    "filter" : camp_fire_filter
}

res = session.post(stats_url, json=request)
printer(res.json())
# Out:
# {
#   "utc_offset": "+0h",
#   "interval": "day",
#   "buckets": [
#     {
#       "count": 46,
#       "start_time": "2018-11-01T00:00:00.000000Z"
#     },
#     {
#       "count": 44,
#       "start_time": "2018-11-02T00:00:00.000000Z"
#     },
#     {
#       "count": 51,
#       "start_time": "2018-11-03T00:00:00.000000Z"
#     },
#     {
#       "count": 64,
#       "start_time": "2018-11-04T00:00:00.000000Z"
#     },
#     {
#       "count": 55,
#       "start_time": "2018-11-05T00:00:00.000000Z"
#     },
#     {
#       "count": 63,
#       "start_time": "2018-11-06T00:00:00.000000Z"
#     },
#     {
#       "count": 41,
#       "start_time": "2018-11-07T00:00:00.000000Z"
#     },
#     {
#       "count": 38,
#       "start_time": "2018-11-08T00:00:00.000000Z"
#     },
#     {
#       "count": 49,
#       "start_time": "2018-11-09T00:00:00.000000Z"
#     },
#     {
#       "count": 50,
#       "start_time": "2018-11-10T00:00:00.000000Z"
#     },
#     {
#       "count": 60,
#       "start_time": "2018-11-11T00:00:00.000000Z"
#     },
#     {
#       "count": 34,
#       "start_time": "2018-11-12T00:00:00.000000Z"
#     },
#     {
#       "count": 62,
#       "start_time": "2018-11-13T00:00:00.000000Z"
#     },
#     {
#       "count": 75,
#       "start_time": "2018-11-14T00:00:00.000000Z"
#     },
#     {
#       "count": 53,
#       "start_time": "2018-11-15T00:00:00.000000Z"
#     },
#     {
#       "count": 42,
#       "start_time": "2018-11-16T00:00:00.000000Z"
#     },
#     {
#       "count": 65,
#       "start_time": "2018-11-17T00:00:00.000000Z"
#     },
#     {
#       "count": 65,
#       "start_time": "2018-11-18T00:00:00.000000Z"
#     },
#     {
#       "count": 51,
#       "start_time": "2018-11-19T00:00:00.000000Z"
#     },
#     {
#       "count": 28,
#       "start_time": "2018-11-20T00:00:00.000000Z"
#     },
#     {
#       "count": 40,
#       "start_time": "2018-11-21T00:00:00.000000Z"
#     },
#     {
#       "count": 82,
#       "start_time": "2018-11-22T00:00:00.000000Z"
#     },
#     {
#       "count": 45,
#       "start_time": "2018-11-23T00:00:00.000000Z"
#     },
#     {
#       "count": 36,
#       "start_time": "2018-11-24T00:00:00.000000Z"
#     },
#     {
#       "count": 46,
#       "start_time": "2018-11-25T00:00:00.000000Z"
#     },
#     {
#       "count": 47,
#       "start_time": "2018-11-26T00:00:00.000000Z"
#     },
#     {
#       "count": 35,
#       "start_time": "2018-11-27T00:00:00.000000Z"
#     },
#     {
#       "count": 36,
#       "start_time": "2018-11-28T00:00:00.000000Z"
#     },
#     {
#       "count": 42,
#       "start_time": "2018-11-29T00:00:00.000000Z"
#     },
#     {
#       "count": 63,
#       "start_time": "2018-11-30T00:00:00.000000Z"
#     }
#   ]
# }

# %%
date_filter = {"type":"DateRangeFilter", 
               "field_name":"acquired", 
               "config":{"gte":"2018-11-01T00:00:00Z",
                         "lte":"2018-12-01T00:00:00Z"
                        }
              }

geo_filter = {"type":"GeometryFilter", 
              "field_name":"geometry", 
              "config":{"type":"Polygon",
                        "coordinates": [
                            [
                                        [
                                          -122.11166381835936,
                                          39.977120098439634
                                        ],
                                        [
                                          -122.0745849609375,
                                          39.48814483559126
                                        ],
                                        [
                                          -121.09268188476562,
                                          39.54641191968671
                                        ],
                                        [
                                          -121.12976074218749,
                                          39.985538414809746
                                        ],
                                        [
                                          -122.11166381835936,
                                          39.977120098439634
                                        ]
                                      ]
                        ]
                       }
             }

# %%
camp_filter = {"type":"AndFilter",
               "config":[date_filter, geo_filter]}

request = {
    "item_types" : item_types,
    "interval" : "month",
    "filter" : camp_filter 
}

res = session.post(stats_url, json=request)
printer(res.json())
# Out:
# {
#   "utc_offset": "+0h",
#   "interval": "month",
#   "buckets": [
#     {
#       "count": 1508,
#       "start_time": "2018-11-01T00:00:00.000000Z"
#     }
#   ]
# }

# %%
camp_fire_filter = {  
   "type":"AndFilter",
   "config":[  
      {  
         "type":"DateRangeFilter",
         "field_name":"acquired",
         "config":{  
            "gte":"2018-11-01T00:00:00Z",
            "lte":"2018-12-01T00:00:00Z"
         }
      },
      {  
         "type":"GeometryFilter",
         "field_name":"geometry",
         "config":{"type":"Polygon",
                   "coordinates": [
          [
            [
              -122.11166381835936,
              39.977120098439634
            ],
            [
              -122.0745849609375,
              39.48814483559126
            ],
            [
              -121.09268188476562,
              39.54641191968671
            ],
            [
              -121.12976074218749,
              39.985538414809746
            ],
            [
              -122.11166381835936,
              39.977120098439634
            ]
          ]
        ]
                  }
      }
    ]
}

# %% [markdown]
# ### Ferguson Fire Coordinates

# %%
ferguson_fire_filter = {  
   "type":"AndFilter",
   "config":[  
      {  
         "type":"DateRangeFilter",
         "field_name":"acquired",
         "config":{  
            "gte":"2018-07-13T00:00:00Z",
            "lte":"2018-08-19T00:00:00Z"
         }
      },
      {  
         "type":"GeometryFilter",
         "field_name":"geometry",
         "config":{"type":"Polygon",
                    "coordinates": [
        [
            [
              -120.39916992187499,
              37.58158917213053
            ],
            [
              -119.49554443359376,
              36.98280911070616
            ],
            [
              -118.67156982421875,
              37.58376576718623
            ],
            [
              -119.4873046875,
              38.20581359813473
            ],
            [
              -120.39916992187499,
              37.58158917213053
            ]
          ]
    ]
                  }
      }
    ]
}

# %%
item_types = ['PSOrthoTile']

request = {
    "item_types" : item_types,
    "interval" : "week",
    "filter" : ferguson_fire_filter 
}

res = session.post(stats_url, json=request)
printer(res.json())
# Out:
# {
#   "utc_offset": "+0h",
#   "interval": "week",
#   "buckets": [
#     {
#       "count": 211,
#       "start_time": "2018-07-09T00:00:00.000000Z"
#     },
#     {
#       "count": 590,
#       "start_time": "2018-07-16T00:00:00.000000Z"
#     },
#     {
#       "count": 549,
#       "start_time": "2018-07-23T00:00:00.000000Z"
#     },
#     {
#       "count": 598,
#       "start_time": "2018-07-30T00:00:00.000000Z"
#     },
#     {
#       "count": 496,
#       "start_time": "2018-08-06T00:00:00.000000Z"
#     },
#     {
#       "count": 499,
#       "start_time": "2018-08-13T00:00:00.000000Z"
#     }
#   ]
# }

# %% [markdown]
# ### Woolesly Fire

# %%
woolesly_fire = {"type": "Polygon", 
                 "coordinates": [
                 [
                  -119.036865234375,
                  33.99575015925125
                 ],
                 [
                  -118.54522705078126,
                  33.99802726234877
                 ],
                 [
                  -118.54248046874999,
                  34.3955786154917
                 ],
                 [
                  -119.04235839843749,
                  34.40464357107094
                 ],
                 [
                  -119.04373168945314,
                  33.99916579100914
                 ]
            ] 
        }

# %% [markdown]
# #### Quick Search

# %%
# Setup the quick search endpoint url
quick_url = "{}/quick-search".format(URL)

# %%
from requests.auth import HTTPBasicAuth


# API Key stored as an env variable
PLANET_API_KEY = 'YOUR API KEY HERE'

item_type = ['PSScene4Band' , "REOrthoTile", "Sentinel2L1C", "PSOrthoTile"]

# API request object
search_request = {
  "interval": "day",
  "item_types": item_type, 
  "filter": ferguson_fire_filter
}

# fire off the POST request
search_result = \
  requests.post(
    'https://api.planet.com/data/v1/quick-search',
    auth=HTTPBasicAuth(PLANET_API_KEY, ''),
    json=search_request)

print(json.dumps(search_result.json(), indent=1))
# Out:
# {
#  "_links": {
#   "_first": "https://api.planet.com/data/v1/searches/b95451996bfe4e7297fa46173350444e/results?_page=eyJxdWVyeV9wYXJhbXMiOiB7fSwgInNvcnRfcHJldiI6IGZhbHNlLCAicGFnZV9zaXplIjogMjUwLCAic29ydF9ieSI6ICJwdWJsaXNoZWQiLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9kZXNjIjogdHJ1ZX0%3D",
#   "_next": "https://api.planet.com/data/v1/searches/b95451996bfe4e7297fa46173350444e/results?_page=%3D",
#   "_self": "https://api.planet.com/data/v1/searches/b95451996bfe4e7297fa46173350444e/results?_page=eyJxdWVyeV9wYXJhbXMiOiB7fSwgInNvcnRfcHJldiI6IGZhbHNlLCAicGFnZV9zaXplIjogMjUwLCAic29ydF9ieSI6ICJwdWJsaXNoZWQiLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9kZXNjIjogdHJ1ZX0%3D"
#  },
#  "features": [
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156605_2018-08-08_1105",
#     "assets": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156605_2018-08-08_1105/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156605_2018-08-08_1105/thumb"
#    },
#    "_permissions": [
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_dn_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -119.5127438060493,
#        37.916164486721634
#       ],
#       [
#        -119.50866684834722,
#        37.93292148378767
#       ],
#       [
#        -119.45815548818578,
#        38.11429513632623
#       ],
#       [
#        -119.45158944051822,
#        37.91751872930969
#       ],
#       [
#        -119.5127438060493,
#        37.916164486721634
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "1616849_1156605_2018-08-08_1105",
#    "properties": {
#     "acquired": "2018-08-08T18:06:00.25315Z",
#     "anomalous_pixels": 0,
#     "black_fill": 0.91,
#     "cloud_cover": 0.001,
#     "columns": 8000,
#     "epsg_code": 32611,
#     "grid_cell": "1156605",
#     "ground_control": true,
#     "gsd": 4,
#     "item_type": "PSOrthoTile",
#     "origin_x": 259500,
#     "origin_y": 4224500,
#     "pixel_resolution": 3.125,
#     "provider": "planetscope",
#     "published": "2018-10-24T18:48:05Z",
#     "rows": 8000,
#     "satellite_id": "1105",
#     "strip_id": "1616849",
#     "sun_azimuth": 122.5,
#     "sun_elevation": 56.2,
#     "updated": "2018-10-25T20:58:46Z",
#     "usable_data": 0.09,
#     "view_angle": 0
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156606_2018-08-08_1105",
#     "assets": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156606_2018-08-08_1105/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156606_2018-08-08_1105/thumb"
#    },
#    "_permissions": [
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_dn_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -119.46286982651348,
#        37.917295287814646
#       ],
#       [
#        -119.468320075231,
#        38.07665100151213
#       ],
#       [
#        -119.45033854599767,
#        38.14280072631251
#       ],
#       [
#        -119.18546504139577,
#        38.1480658166186
#       ],
#       [
#        -119.18117350697254,
#        38.00449007108732
#       ],
#       [
#        -119.20426196216954,
#        37.92240734439158
#       ],
#       [
#        -119.46286982651348,
#        37.917295287814646
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "1616849_1156606_2018-08-08_1105",
#    "properties": {
#     "acquired": "2018-08-08T18:05:59.709463Z",
#     "anomalous_pixels": 0,
#     "black_fill": 0.07,
#     "cloud_cover": 0.002,
#     "columns": 8000,
#     "epsg_code": 32611,
#     "grid_cell": "1156606",
#     "ground_control": true,
#     "gsd": 4,
#     "item_type": "PSOrthoTile",
#     "origin_x": 283500,
#     "origin_y": 4224500,
#     "pixel_resolution": 3.125,
#     "provider": "planetscope",
#     "published": "2018-10-24T18:47:58Z",
#     "rows": 8000,
#     "satellite_id": "1105",
#     "strip_id": "1616849",
#     "sun_azimuth": 122.5,
#     "sun_elevation": 56.2,
#     "updated": "2018-10-25T20:58:39Z",
#     "usable_data": 0.93,
#     "view_angle": 0
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156506_2018-08-08_1105",
#     "assets": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156506_2018-08-08_1105/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156506_2018-08-08_1105/thumb"
#    },
#    "_permissions": [
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_dn_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -119.45578876613526,
#        37.701177093221084
#       ],
#       [
#        -119.46325603603165,
#        37.92629579690811
#       ],
#       [
#        -119.20181575896837,
#        37.931441077194485
#       ],
#       [
#        -119.26575962187452,
#        37.70494601251789
#       ],
#       [
#        -119.45578876613526,
#        37.701177093221084
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "1616849_1156506_2018-08-08_1105",
#    "properties": {
#     "acquired": "2018-08-08T18:06:02.971321Z",
#     "anomalous_pixels": 0,
#     "black_fill": 0.24,
#     "cloud_cover": 0.001,
#     "columns": 8000,
#     "epsg_code": 32611,
#     "grid_cell": "1156506",
#     "ground_control": true,
#     "gsd": 4,
#     "item_type": "PSOrthoTile",
#     "origin_x": 283500,
#     "origin_y": 4200500,
#     "pixel_resolution": 3.125,
#     "provider": "planetscope",
#     "published": "2018-10-24T18:47:57Z",
#     "rows": 8000,
#     "satellite_id": "1105",
#     "strip_id": "1616849",
#     "sun_azimuth": 122.2,
#     "sun_elevation": 56.2,
#     "updated": "2018-10-25T20:58:38Z",
#     "usable_data": 0.76,
#     "view_angle": 0
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156607_2018-08-08_1105",
#     "assets": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156607_2018-08-08_1105/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156607_2018-08-08_1105/thumb"
#    },
#    "_permissions": [
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_dn_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -119.19151755183991,
#        37.96960189513825
#       ],
#       [
#        -119.19683905452474,
#        38.147847438952866
#       ],
#       [
#        -119.14087744564578,
#        38.14882616678498
#       ],
#       [
#        -119.17581053585089,
#        38.022969007575114
#       ],
#       [
#        -119.19151755183991,
#        37.96960189513825
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "1616849_1156607_2018-08-08_1105",
#    "properties": {
#     "acquired": "2018-08-08T18:05:59.166038Z",
#     "anomalous_pixels": 0,
#     "black_fill": 0.92,
#     "cloud_cover": 0,
#     "columns": 8000,
#     "epsg_code": 32611,
#     "grid_cell": "1156607",
#     "ground_control": true,
#     "gsd": 4,
#     "item_type": "PSOrthoTile",
#     "origin_x": 307500,
#     "origin_y": 4224500,
#     "pixel_resolution": 3.125,
#     "provider": "planetscope",
#     "published": "2018-10-24T18:47:38Z",
#     "rows": 8000,
#     "satellite_id": "1105",
#     "strip_id": "1616849",
#     "sun_azimuth": 122.6,
#     "sun_elevation": 56.2,
#     "updated": "2018-10-25T20:58:02Z",
#     "usable_data": 0.08,
#     "view_angle": 0
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156105_2018-08-08_1105",
#     "assets": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156105_2018-08-08_1105/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156105_2018-08-08_1105/thumb"
#    },
#    "_permissions": [
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_dn_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -119.6967400479139,
#        36.83081386331138
#       ],
#       [
#        -119.7046793865969,
#        37.05591939857341
#       ],
#       [
#        -119.44401158572978,
#        37.06157018979452
#       ],
#       [
#        -119.50611008883394,
#        36.83493573210119
#       ],
#       [
#        -119.6967400479139,
#        36.83081386331138
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "1616849_1156105_2018-08-08_1105",
#    "properties": {
#     "acquired": "2018-08-08T18:06:17.105077Z",
#     "anomalous_pixels": 0.16,
#     "black_fill": 0.24,
#     "cloud_cover": 0.161,
#     "columns": 8000,
#     "epsg_code": 32611,
#     "grid_cell": "1156105",
#     "ground_control": true,
#     "gsd": 4,
#     "item_type": "PSOrthoTile",
#     "origin_x": 259500,
#     "origin_y": 4104500,
#     "pixel_resolution": 3.125,
#     "provider": "planetscope",
#     "published": "2018-10-24T18:47:38Z",
#     "rows": 8000,
#     "satellite_id": "1105",
#     "strip_id": "1616849",
#     "sun_azimuth": 120.9,
#     "sun_elevation": 56.6,
#     "updated": "2018-10-25T20:58:02Z",
#     "usable_data": 0.6,
#     "view_angle": 0
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156206_2018-08-08_1105",
#     "assets": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156206_2018-08-08_1105/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156206_2018-08-08_1105/thumb"
#    },
#    "_permissions": [
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_dn_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -119.4356487382333,
#        37.091403722030954
#       ],
#       [
#        -119.44195729383544,
#        37.277911643493674
#       ],
#       [
#        -119.38449364790839,
#        37.279072667950075
#       ],
#       [
#        -119.41565018782104,
#        37.16342880856727
#       ],
#       [
#        -119.4356487382333,
#        37.091403722030954
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "1616849_1156206_2018-08-08_1105",
#    "properties": {
#     "acquired": "2018-08-08T18:06:13.299795Z",
#     "anomalous_pixels": 0.02,
#     "black_fill": 0.92,
#     "cloud_cover": 0.024,
#     "columns": 8000,
#     "epsg_code": 32611,
#     "grid_cell": "1156206",
#     "ground_control": true,
#     "gsd": 4,
#     "item_type": "PSOrthoTile",
#     "origin_x": 283500,
#     "origin_y": 4128500,
#     "pixel_resolution": 3.125,
#     "provider": "planetscope",
#     "published": "2018-10-24T18:47:37Z",
#     "rows": 8000,
#     "satellite_id": "1105",
#     "strip_id": "1616849",
#     "sun_azimuth": 121.2,
#     "sun_elevation": 56.5,
#     "updated": "2018-10-25T20:58:01Z",
#     "usable_data": 0.06,
#     "view_angle": 0
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156205_2018-08-08_1105",
#     "assets": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156205_2018-08-08_1105/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156205_2018-08-08_1105/thumb"
#    },
#    "_permissions": [
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_dn_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -119.70437095060161,
#        37.04693290386337
#       ],
#       [
#        -119.70990703000759,
#        37.20224592507898
#       ],
#       [
#        -119.69089553251264,
#        37.27252623728399
#       ],
#       [
#        -119.4306998004321,
#        37.278160856353104
#       ],
#       [
#        -119.4258074511896,
#        37.12632299622741
#       ],
#       [
#        -119.44632098573267,
#        37.05251586425397
#       ],
#       [
#        -119.70437095060161,
#        37.04693290386337
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "1616849_1156205_2018-08-08_1105",
#    "properties": {
#     "acquired": "2018-08-08T18:06:13.843481Z",
#     "anomalous_pixels": 0.06,
#     "black_fill": 0.08,
#     "cloud_cover": 0.063,
#     "columns": 8000,
#     "epsg_code": 32611,
#     "grid_cell": "1156205",
#     "ground_control": true,
#     "gsd": 4,
#     "item_type": "PSOrthoTile",
#     "origin_x": 259500,
#     "origin_y": 4128500,
#     "pixel_resolution": 3.125,
#     "provider": "planetscope",
#     "published": "2018-10-24T18:47:37Z",
#     "rows": 8000,
#     "satellite_id": "1105",
#     "strip_id": "1616849",
#     "sun_azimuth": 121.2,
#     "sun_elevation": 56.5,
#     "updated": "2018-10-25T20:58:01Z",
#     "usable_data": 0.86,
#     "view_angle": 0
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156204_2018-08-08_1105",
#     "assets": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156204_2018-08-08_1105/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156204_2018-08-08_1105/thumb"
#    },
#    "_permissions": [
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_dn_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -119.75285465567225,
#        37.04577627270367
#       ],
#       [
#        -119.74676067679127,
#        37.068585390752204
#       ],
#       [
#        -119.69998295157802,
#        37.23943509000777
#       ],
#       [
#        -119.69311649650086,
#        37.047180635681535
#       ],
#       [
#        -119.75285465567225,
#        37.04577627270367
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "1616849_1156204_2018-08-08_1105",
#    "properties": {
#     "acquired": "2018-08-08T18:06:14.387168Z",
#     "anomalous_pixels": 0,
#     "black_fill": 0.91,
#     "cloud_cover": 0.005,
#     "columns": 8000,
#     "epsg_code": 32611,
#     "grid_cell": "1156204",
#     "ground_control": true,
#     "gsd": 4,
#     "item_type": "PSOrthoTile",
#     "origin_x": 235500,
#     "origin_y": 4128500,
#     "pixel_resolution": 3.125,
#     "provider": "planetscope",
#     "published": "2018-10-24T18:47:37Z",
#     "rows": 8000,
#     "satellite_id": "1105",
#     "strip_id": "1616849",
#     "sun_azimuth": 121.1,
#     "sun_elevation": 56.5,
#     "updated": "2018-10-25T20:58:01Z",
#     "usable_data": 0.08,
#     "view_angle": 0
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156306_2018-08-08_1105",
#     "assets": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156306_2018-08-08_1105/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156306_2018-08-08_1105/thumb"
#    },
#    "_permissions": [
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_dn_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -119.44164264495934,
#        37.26893639573079
#       ],
#       [
#        -119.44898116882307,
#        37.494070816112426
#       ],
#       [
#        -119.32542789277822,
#        37.496488308173404
#       ],
#       [
#        -119.38688266571889,
#        37.27002925540988
#       ],
#       [
#        -119.44164264495934,
#        37.26893639573079
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "1616849_1156306_2018-08-08_1105",
#    "properties": {
#     "acquired": "2018-08-08T18:06:09.494512Z",
#     "anomalous_pixels": 0.05,
#     "black_fill": 0.7,
#     "cloud_cover": 0.052,
#     "columns": 8000,
#     "epsg_code": 32611,
#     "grid_cell": "1156306",
#     "ground_control": true,
#     "gsd": 4,
#     "item_type": "PSOrthoTile",
#     "origin_x": 283500,
#     "origin_y": 4152500,
#     "pixel_resolution": 3.125,
#     "provider": "planetscope",
#     "published": "2018-10-24T18:47:36Z",
#     "rows": 8000,
#     "satellite_id": "1105",
#     "strip_id": "1616849",
#     "sun_azimuth": 121.6,
#     "sun_elevation": 56.4,
#     "updated": "2018-10-25T20:57:59Z",
#     "usable_data": 0.25,
#     "view_angle": 0
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156305_2018-08-08_1105",
#     "assets": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156305_2018-08-08_1105/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156305_2018-08-08_1105/thumb"
#    },
#    "_permissions": [
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_dn_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -119.69337355722344,
#        37.263425809415594
#       ],
#       [
#        -119.63221919169239,
#        37.490040979797946
#       ],
#       [
#        -119.43768393628729,
#        37.49429730504849
#       ],
#       [
#        -119.43038832776779,
#        37.269197717657796
#       ],
#       [
#        -119.69337355722344,
#        37.263425809415594
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "1616849_1156305_2018-08-08_1105",
#    "properties": {
#     "acquired": "2018-08-08T18:06:10.581885Z",
#     "anomalous_pixels": 0.05,
#     "black_fill": 0.23,
#     "cloud_cover": 0.047,
#     "columns": 8000,
#     "epsg_code": 32611,
#     "grid_cell": "1156305",
#     "ground_control": true,
#     "gsd": 4,
#     "item_type": "PSOrthoTile",
#     "origin_x": 259500,
#     "origin_y": 4152500,
#     "pixel_resolution": 3.125,
#     "provider": "planetscope",
#     "published": "2018-10-24T18:47:36Z",
#     "rows": 8000,
#     "satellite_id": "1105",
#     "strip_id": "1616849",
#     "sun_azimuth": 121.5,
#     "sun_elevation": 56.4,
#     "updated": "2018-10-25T20:57:59Z",
#     "usable_data": 0.72,
#     "view_angle": 0
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156505_2018-08-08_1105",
#     "assets": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156505_2018-08-08_1105/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156505_2018-08-08_1105/thumb"
#    },
#    "_permissions": [
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_dn_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -119.57301144847759,
#        37.69857279151363
#       ],
#       [
#        -119.51056962261956,
#        37.925256641210424
#       ],
#       [
#        -119.45190434705398,
#        37.926543013218286
#       ],
#       [
#        -119.44443707715754,
#        37.70142506449791
#       ],
#       [
#        -119.57301144847759,
#        37.69857279151363
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "1616849_1156505_2018-08-08_1105",
#    "properties": {
#     "acquired": "2018-08-08T18:06:03.515007Z",
#     "anomalous_pixels": 0.02,
#     "black_fill": 0.69,
#     "cloud_cover": 0.023,
#     "columns": 8000,
#     "epsg_code": 32611,
#     "grid_cell": "1156505",
#     "ground_control": true,
#     "gsd": 4,
#     "item_type": "PSOrthoTile",
#     "origin_x": 259500,
#     "origin_y": 4200500,
#     "pixel_resolution": 3.125,
#     "provider": "planetscope",
#     "published": "2018-10-24T18:47:35Z",
#     "rows": 8000,
#     "satellite_id": "1105",
#     "strip_id": "1616849",
#     "sun_azimuth": 122.2,
#     "sun_elevation": 56.3,
#     "updated": "2018-10-25T20:57:53Z",
#     "usable_data": 0.29,
#     "view_angle": 0
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156406_2018-08-08_1105",
#     "assets": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156406_2018-08-08_1105/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156406_2018-08-08_1105/thumb"
#    },
#    "_permissions": [
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_dn_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -119.44865610921966,
#        37.48505746025307
#       ],
#       [
#        -119.45608046377185,
#        37.71018749286307
#       ],
#       [
#        -119.26330473748027,
#        37.71395595398021
#       ],
#       [
#        -119.32780649986142,
#        37.48744119129629
#       ],
#       [
#        -119.44865610921966,
#        37.48505746025307
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "1616849_1156406_2018-08-08_1105",
#    "properties": {
#     "acquired": "2018-08-08T18:06:06.232916Z",
#     "anomalous_pixels": 0,
#     "black_fill": 0.47,
#     "cloud_cover": 0.001,
#     "columns": 8000,
#     "epsg_code": 32611,
#     "grid_cell": "1156406",
#     "ground_control": true,
#     "gsd": 4,
#     "item_type": "PSOrthoTile",
#     "origin_x": 283500,
#     "origin_y": 4176500,
#     "pixel_resolution": 3.125,
#     "provider": "planetscope",
#     "published": "2018-10-24T18:47:35Z",
#     "rows": 8000,
#     "satellite_id": "1105",
#     "strip_id": "1616849",
#     "sun_azimuth": 121.9,
#     "sun_elevation": 56.3,
#     "updated": "2018-10-25T20:57:53Z",
#     "usable_data": 0.53,
#     "view_angle": 0
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156706_2018-08-08_1105",
#     "assets": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156706_2018-08-08_1105/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156706_2018-08-08_1105/thumb"
#    },
#    "_permissions": [
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_dn_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -119.45286278601691,
#        38.13374959792124
#       ],
#       [
#        -119.39007763740504,
#        38.36023706002816
#       ],
#       [
#        -119.19193749308441,
#        38.364207765117456
#       ],
#       [
#        -119.18515686869569,
#        38.139116601942035
#       ],
#       [
#        -119.45286278601691,
#        38.13374959792124
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "1616849_1156706_2018-08-08_1105",
#    "properties": {
#     "acquired": "2018-08-08T18:05:56.447867Z",
#     "anomalous_pixels": 0,
#     "black_fill": 0.22,
#     "cloud_cover": 0.001,
#     "columns": 8000,
#     "epsg_code": 32611,
#     "grid_cell": "1156706",
#     "ground_control": true,
#     "gsd": 4,
#     "item_type": "PSOrthoTile",
#     "origin_x": 283500,
#     "origin_y": 4248500,
#     "pixel_resolution": 3.125,
#     "provider": "planetscope",
#     "published": "2018-10-24T18:47:21Z",
#     "rows": 8000,
#     "satellite_id": "1105",
#     "strip_id": "1616849",
#     "sun_azimuth": 122.9,
#     "sun_elevation": 56.1,
#     "updated": "2018-10-25T20:57:44Z",
#     "usable_data": 0.78,
#     "view_angle": 0
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156405_2018-08-08_1105",
#     "assets": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156405_2018-08-08_1105/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSOrthoTile/items/1616849_1156405_2018-08-08_1105/thumb"
#    },
#    "_permissions": [
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_dn_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -119.63456636891993,
#        37.48097043752598
#       ],
#       [
#        -119.57070833670225,
#        37.707674630648306
#       ],
#       [
#        -119.44475180138039,
#        37.71042470091072
#       ],
#       [
#        -119.43737036217243,
#        37.4852953871062
#       ],
#       [
#        -119.63456636891993,
#        37.48097043752598
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "1616849_1156405_2018-08-08_1105",
#    "properties": {
#     "acquired": "2018-08-08T18:06:07.320028Z",
#     "anomalous_pixels": 0,
#     "black_fill": 0.46,
#     "cloud_cover": 0.004,
#     "columns": 8000,
#     "epsg_code": 32611,
#     "grid_cell": "1156405",
#     "ground_control": true,
#     "gsd": 4,
#     "item_type": "PSOrthoTile",
#     "origin_x": 259500,
#     "origin_y": 4176500,
#     "pixel_resolution": 3.125,
#     "provider": "planetscope",
#     "published": "2018-10-24T18:47:18Z",
#     "rows": 8000,
#     "satellite_id": "1105",
#     "strip_id": "1616849",
#     "sun_azimuth": 121.8,
#     "sun_elevation": 56.4,
#     "updated": "2018-10-25T20:57:40Z",
#     "usable_data": 0.54,
#     "view_angle": 0
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1587955_1156606_2018-07-25_1105",
#     "assets": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1587955_1156606_2018-07-25_1105/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSOrthoTile/items/1587955_1156606_2018-07-25_1105/thumb"
#    },
#    "_permissions": [
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_dn_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -119.42931002732384,
#        37.9179724018156
#       ],
#       [
#        -119.36532324907344,
#        38.14448829663435
#       ],
#       [
#        -119.18546504139577,
#        38.1480658166186
#       ],
#       [
#        -119.17877024769555,
#        37.922915145179395
#       ],
#       [
#        -119.42931002732384,
#        37.9179724018156
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "1587955_1156606_2018-07-25_1105",
#    "properties": {
#     "acquired": "2018-07-25T18:04:44.737039Z",
#     "anomalous_pixels": 0.01,
#     "black_fill": 0.28,
#     "cloud_cover": 0.009,
#     "columns": 8000,
#     "epsg_code": 32611,
#     "grid_cell": "1156606",
#     "ground_control": true,
#     "gsd": 4,
#     "item_type": "PSOrthoTile",
#     "origin_x": 283500,
#     "origin_y": 4224500,
#     "pixel_resolution": 3.125,
#     "provider": "planetscope",
#     "published": "2018-10-24T18:05:56Z",
#     "rows": 8000,
#     "satellite_id": "1105",
#     "strip_id": "1587955",
#     "sun_azimuth": 117.3,
#     "sun_elevation": 58.3,
#     "updated": "2018-10-25T21:25:16Z",
#     "usable_data": 0.71,
#     "view_angle": 0
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1587955_1156405_2018-07-25_1105",
#     "assets": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1587955_1156405_2018-07-25_1105/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSOrthoTile/items/1587955_1156405_2018-07-25_1105/thumb"
#    },
#    "_permissions": [
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_dn_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -119.54749113547257,
#        37.482877532765535
#       ],
#       [
#        -119.48530680167994,
#        37.70947407087991
#       ],
#       [
#        -119.44475180138039,
#        37.71042470091072
#       ],
#       [
#        -119.43737036217243,
#        37.48536349454606
#       ],
#       [
#        -119.54749113547257,
#        37.482877532765535
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "1587955_1156405_2018-07-25_1105",
#    "properties": {
#     "acquired": "2018-07-25T18:04:52.280495Z",
#     "anomalous_pixels": 0.03,
#     "black_fill": 0.75,
#     "cloud_cover": 0.032,
#     "columns": 8000,
#     "epsg_code": 32611,
#     "grid_cell": "1156405",
#     "ground_control": true,
#     "gsd": 4,
#     "item_type": "PSOrthoTile",
#     "origin_x": 259500,
#     "origin_y": 4176500,
#     "pixel_resolution": 3.125,
#     "provider": "planetscope",
#     "published": "2018-10-24T18:05:55Z",
#     "rows": 8000,
#     "satellite_id": "1105",
#     "strip_id": "1587955",
#     "sun_azimuth": 116.5,
#     "sun_elevation": 58.5,
#     "updated": "2018-10-25T21:25:15Z",
#     "usable_data": 0.22,
#     "view_angle": 0
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1587955_1156406_2018-07-25_1105",
#     "assets": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1587955_1156406_2018-07-25_1105/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSOrthoTile/items/1587955_1156406_2018-07-25_1105/thumb"
#    },
#    "_permissions": [
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_dn_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -119.44869902456388,
#        37.48505746025307
#       ],
#       [
#        -119.45608046377185,
#        37.71018749286307
#       ],
#       [
#        -119.17652991144253,
#        37.715687344830414
#       ],
#       [
#        -119.2159261974478,
#        37.570483699461214
#       ],
#       [
#        -119.23987295952942,
#        37.4891778617328
#       ],
#       [
#        -119.44869902456388,
#        37.48505746025307
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "1587955_1156406_2018-07-25_1105",
#    "properties": {
#     "acquired": "2018-07-25T18:04:51.203083Z",
#     "anomalous_pixels": 0.01,
#     "black_fill": 0.18,
#     "cloud_cover": 0.007,
#     "columns": 8000,
#     "epsg_code": 32611,
#     "grid_cell": "1156406",
#     "ground_control": true,
#     "gsd": 4,
#     "item_type": "PSOrthoTile",
#     "origin_x": 283500,
#     "origin_y": 4176500,
#     "pixel_resolution": 3.125,
#     "provider": "planetscope",
#     "published": "2018-10-24T18:05:50Z",
#     "rows": 8000,
#     "satellite_id": "1105",
#     "strip_id": "1587955",
#     "sun_azimuth": 116.6,
#     "sun_elevation": 58.5,
#     "updated": "2018-10-25T21:25:15Z",
#     "usable_data": 0.82,
#     "view_angle": 0
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1587955_1156507_2018-07-25_1105",
#     "assets": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1587955_1156507_2018-07-25_1105/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSOrthoTile/items/1587955_1156507_2018-07-25_1105/thumb"
#    },
#    "_permissions": [
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_dn_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -119.18373620551874,
#        37.7065426990493
#       ],
#       [
#        -119.19038808387475,
#        37.931678915062484
#       ],
#       [
#        -119.11665952248362,
#        37.93299902334448
#       ],
#       [
#        -119.17901551765317,
#        37.70664455687899
#       ],
#       [
#        -119.18373620551874,
#        37.7065426990493
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "1587955_1156507_2018-07-25_1105",
#    "properties": {
#     "acquired": "2018-07-25T18:04:47.969799Z",
#     "anomalous_pixels": 0,
#     "black_fill": 0.87,
#     "cloud_cover": 0,
#     "columns": 8000,
#     "epsg_code": 32611,
#     "grid_cell": "1156507",
#     "ground_control": true,
#     "gsd": 4,
#     "item_type": "PSOrthoTile",
#     "origin_x": 307500,
#     "origin_y": 4200500,
#     "pixel_resolution": 3.125,
#     "provider": "planetscope",
#     "published": "2018-10-24T18:05:49Z",
#     "rows": 8000,
#     "satellite_id": "1105",
#     "strip_id": "1587955",
#     "sun_azimuth": 116.9,
#     "sun_elevation": 58.4,
#     "updated": "2018-10-25T21:25:14Z",
#     "usable_data": 0.13,
#     "view_angle": 0
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1587955_1156506_2018-07-25_1105",
#     "assets": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1587955_1156506_2018-07-25_1105/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSOrthoTile/items/1587955_1156506_2018-07-25_1105/thumb"
#    },
#    "_permissions": [
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_dn_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -119.45578876613526,
#        37.701177093221084
#       ],
#       [
#        -119.45922199367382,
#        37.804226955777864
#       ],
#       [
#        -119.42669216274572,
#        37.92704053081492
#       ],
#       [
#        -119.17902771118102,
#        37.931914966479376
#       ],
#       [
#        -119.1730195629885,
#        37.72887926901423
#       ],
#       [
#        -119.17902771118102,
#        37.706643661309144
#       ],
#       [
#        -119.45578876613526,
#        37.701177093221084
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "1587955_1156506_2018-07-25_1105",
#    "properties": {
#     "acquired": "2018-07-25T18:04:47.969799Z",
#     "anomalous_pixels": 0.03,
#     "black_fill": 0.08,
#     "cloud_cover": 0.028,
#     "columns": 8000,
#     "epsg_code": 32611,
#     "grid_cell": "1156506",
#     "ground_control": true,
#     "gsd": 4,
#     "item_type": "PSOrthoTile",
#     "origin_x": 283500,
#     "origin_y": 4200500,
#     "pixel_resolution": 3.125,
#     "provider": "planetscope",
#     "published": "2018-10-24T18:05:49Z",
#     "rows": 8000,
#     "satellite_id": "1105",
#     "strip_id": "1587955",
#     "sun_azimuth": 116.9,
#     "sun_elevation": 58.4,
#     "updated": "2018-10-25T21:25:14Z",
#     "usable_data": 0.89,
#     "view_angle": 0
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1587955_1156205_2018-07-25_1105",
#     "assets": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1587955_1156205_2018-07-25_1105/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSOrthoTile/items/1587955_1156205_2018-07-25_1105/thumb"
#    },
#    "_permissions": [
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_dn_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -119.66531798735019,
#        37.047789212795294
#       ],
#       [
#        -119.60467860594993,
#        37.27437034086133
#       ],
#       [
#        -119.4306998004321,
#        37.278160856353104
#       ],
#       [
#        -119.42349002260107,
#        37.052995363172705
#       ],
#       [
#        -119.66531798735019,
#        37.047789212795294
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "1587955_1156205_2018-07-25_1105",
#    "properties": {
#     "acquired": "2018-07-25T18:04:58.746539Z",
#     "anomalous_pixels": 0.67,
#     "black_fill": 0.3,
#     "cloud_cover": 0.671,
#     "columns": 8000,
#     "epsg_code": 32611,
#     "grid_cell": "1156205",
#     "ground_control": true,
#     "gsd": 4,
#     "item_type": "PSOrthoTile",
#     "origin_x": 259500,
#     "origin_y": 4128500,
#     "pixel_resolution": 3.125,
#     "provider": "planetscope",
#     "published": "2018-10-24T18:05:45Z",
#     "rows": 8000,
#     "satellite_id": "1105",
#     "strip_id": "1587955",
#     "sun_azimuth": 115.8,
#     "sun_elevation": 58.6,
#     "updated": "2018-10-25T21:25:01Z",
#     "usable_data": 0.03,
#     "view_angle": 0
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1587955_1156607_2018-07-25_1105",
#     "assets": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1587955_1156607_2018-07-25_1105/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSOrthoTile/items/1587955_1156607_2018-07-25_1105/thumb"
#    },
#    "_permissions": [
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_dn_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -119.19010134548024,
#        37.92269609517109
#       ],
#       [
#        -119.19683905452474,
#        38.147847438952866
#       ],
#       [
#        -119.05393095823109,
#        38.150344856388045
#       ],
#       [
#        -119.11907645077576,
#        37.92401636474196
#       ],
#       [
#        -119.19010134548024,
#        37.92269609517109
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "1587955_1156607_2018-07-25_1105",
#    "properties": {
#     "acquired": "2018-07-25T18:04:44.198333Z",
#     "anomalous_pixels": 0.02,
#     "black_fill": 0.64,
#     "cloud_cover": 0.018,
#     "columns": 8000,
#     "epsg_code": 32611,
#     "grid_cell": "1156607",
#     "ground_control": true,
#     "gsd": 4,
#     "item_type": "PSOrthoTile",
#     "origin_x": 307500,
#     "origin_y": 4224500,
#     "pixel_resolution": 3.125,
#     "provider": "planetscope",
#     "published": "2018-10-24T18:05:35Z",
#     "rows": 8000,
#     "satellite_id": "1105",
#     "strip_id": "1587955",
#     "sun_azimuth": 117.3,
#     "sun_elevation": 58.3,
#     "updated": "2018-10-25T21:24:53Z",
#     "usable_data": 0.34,
#     "view_angle": 0
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1587955_1156106_2018-07-25_1105",
#     "assets": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1587955_1156106_2018-07-25_1105/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSOrthoTile/items/1587955_1156106_2018-07-25_1105/thumb"
#    },
#    "_permissions": [
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_dn_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -119.42784113351048,
#        36.83662130537029
#       ],
#       [
#        -119.43500799599728,
#        37.06177819839052
#       ],
#       [
#        -119.35565752451171,
#        37.063319246000916
#       ],
#       [
#        -119.41715521279663,
#        36.83686173556224
#       ],
#       [
#        -119.42784113351048,
#        36.83662130537029
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "1587955_1156106_2018-07-25_1105",
#    "properties": {
#     "acquired": "2018-07-25T18:05:01.440331Z",
#     "anomalous_pixels": 0.15,
#     "black_fill": 0.85,
#     "cloud_cover": 0.153,
#     "columns": 8000,
#     "epsg_code": 32611,
#     "grid_cell": "1156106",
#     "ground_control": true,
#     "gsd": 4,
#     "item_type": "PSOrthoTile",
#     "origin_x": 283500,
#     "origin_y": 4104500,
#     "pixel_resolution": 3.125,
#     "provider": "planetscope",
#     "published": "2018-10-24T18:05:34Z",
#     "rows": 8000,
#     "satellite_id": "1105",
#     "strip_id": "1587955",
#     "sun_azimuth": 115.5,
#     "sun_elevation": 58.6,
#     "updated": "2018-10-25T21:24:52Z",
#     "usable_data": 0,
#     "view_angle": 0
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1587955_1156105_2018-07-25_1105",
#     "assets": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1587955_1156105_2018-07-25_1105/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSOrthoTile/items/1587955_1156105_2018-07-25_1105/thumb"
#    },
#    "_permissions": [
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_dn_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -119.6967400479139,
#        36.83081386331138
#       ],
#       [
#        -119.69987286804287,
#        36.92055161515793
#       ],
#       [
#        -119.66283692597035,
#        37.056844102299586
#       ],
#       [
#        -119.42375554325211,
#        37.06201538576258
#       ],
#       [
#        -119.41714658024033,
#        36.836893541972
#       ],
#       [
#        -119.6967400479139,
#        36.83081386331138
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "1587955_1156105_2018-07-25_1105",
#    "properties": {
#     "acquired": "2018-07-25T18:05:01.9793Z",
#     "anomalous_pixels": 0.65,
#     "black_fill": 0.09,
#     "cloud_cover": 0.652,
#     "columns": 8000,
#     "epsg_code": 32611,
#     "grid_cell": "1156105",
#     "ground_control": true,
#     "gsd": 4,
#     "item_type": "PSOrthoTile",
#     "origin_x": 259500,
#     "origin_y": 4104500,
#     "pixel_resolution": 3.125,
#     "provider": "planetscope",
#     "published": "2018-10-24T18:05:34Z",
#     "rows": 8000,
#     "satellite_id": "1105",
#     "strip_id": "1587955",
#     "sun_azimuth": 115.4,
#     "sun_elevation": 58.6,
#     "updated": "2018-10-25T21:24:53Z",
#     "usable_data": 0.25,
#     "view_angle": 0
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1587955_1156206_2018-07-25_1105",
#     "assets": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1587955_1156206_2018-07-25_1105/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSOrthoTile/items/1587955_1156206_2018-07-25_1105/thumb"
#    },
#    "_permissions": [
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_dn_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -119.4347046006602,
#        37.052779656666246
#       ],
#       [
#        -119.44195729383544,
#        37.277945791527415
#       ],
#       [
#        -119.2976759065264,
#        37.280745877575576
#       ],
#       [
#        -119.35805779586127,
#        37.05428663782748
#       ],
#       [
#        -119.4347046006602,
#        37.052779656666246
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "1587955_1156206_2018-07-25_1105",
#    "properties": {
#     "acquired": "2018-07-25T18:04:58.207571Z",
#     "anomalous_pixels": 0.36,
#     "black_fill": 0.63,
#     "cloud_cover": 0.355,
#     "columns": 8000,
#     "epsg_code": 32611,
#     "grid_cell": "1156206",
#     "ground_control": true,
#     "gsd": 4,
#     "item_type": "PSOrthoTile",
#     "origin_x": 283500,
#     "origin_y": 4128500,
#     "pixel_resolution": 3.125,
#     "provider": "planetscope",
#     "published": "2018-10-24T18:05:22Z",
#     "rows": 8000,
#     "satellite_id": "1105",
#     "strip_id": "1587955",
#     "sun_azimuth": 115.8,
#     "sun_elevation": 58.6,
#     "updated": "2018-10-25T21:24:49Z",
#     "usable_data": 0.02,
#     "view_angle": 0
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1587955_1156306_2018-07-25_1105",
#     "assets": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1587955_1156306_2018-07-25_1105/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSOrthoTile/items/1587955_1156306_2018-07-25_1105/thumb"
#    },
#    "_permissions": [
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_dn_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -119.44164264495934,
#        37.26893639573079
#       ],
#       [
#        -119.44898116882307,
#        37.494070816112426
#       ],
#       [
#        -119.23753726779043,
#        37.49822476826036
#       ],
#       [
#        -119.30006492433691,
#        37.27166851518658
#       ],
#       [
#        -119.44164264495934,
#        37.26893639573079
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "1587955_1156306_2018-07-25_1105",
#    "properties": {
#     "acquired": "2018-07-25T18:04:54.435843Z",
#     "anomalous_pixels": 0.19,
#     "black_fill": 0.4,
#     "cloud_cover": 0.189,
#     "columns": 8000,
#     "epsg_code": 32611,
#     "grid_cell": "1156306",
#     "ground_control": true,
#     "gsd": 4,
#     "item_type": "PSOrthoTile",
#     "origin_x": 283500,
#     "origin_y": 4152500,
#     "pixel_resolution": 3.125,
#     "provider": "planetscope",
#     "published": "2018-10-24T18:05:20Z",
#     "rows": 8000,
#     "satellite_id": "1105",
#     "strip_id": "1587955",
#     "sun_azimuth": 116.2,
#     "sun_elevation": 58.5,
#     "updated": "2018-10-25T21:24:48Z",
#     "usable_data": 0.41,
#     "view_angle": 0
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1587955_1156305_2018-07-25_1105",
#     "assets": "https://api.planet.com/data/v1/item-types/PSOrthoTile/items/1587955_1156305_2018-07-25_1105/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSOrthoTile/items/1587955_1156305_2018-07-25_1105/thumb"
#    },
#    "_permissions": [
#     "assets.analytic_xml:download",
#     "assets.analytic_dn:download",
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_dn_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -119.60724246134914,
#        37.265304289653066
#       ],
#       [
#        -119.57703005900964,
#        37.38133750951456
#       ],
#       [
#        -119.54510104290078,
#        37.49194784350121
#       ],
#       [
#        -119.43768393628729,
#        37.49429730504849
#       ],
#       [
#        -119.43038832776779,
#        37.26916356565575
#       ],
#       [
#        -119.60724246134914,
#        37.265304289653066
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "1587955_1156305_2018-07-25_1105",
#    "properties": {
#     "acquired": "2018-07-25T18:04:55.513255Z",
#     "anomalous_pixels": 0.33,
#     "black_fill": 0.52,
#     "cloud_cover": 0.332,
#     "columns": 8000,
#     "epsg_code": 32611,
#     "grid_cell": "1156305",
#     "ground_control": true,
#     "gsd": 4,
#     "item_type": "PSOrthoTile",
#     "origin_x": 259500,
#     "origin_y": 4152500,
#     "pixel_resolution": 3.125,
#     "provider": "planetscope",
# ...
#     "cloud_cover": 0,
#     "columns": 8882,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 3.8,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "origin_x": 285723,
#     "origin_y": 4152633,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2018-08-18T20:38:57Z",
#     "quality_category": "standard",
#     "rows": 4655,
#     "satellite_id": "1044",
#     "strip_id": "1638770",
#     "sun_azimuth": 128.4,
#     "sun_elevation": 55.7,
#     "updated": "2018-12-18T23:58:29Z",
#     "usable_data": 0,
#     "view_angle": 0.1
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180818_181300_1044",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180818_181300_1044/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20180818_181300_1044/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -119.36518979952596,
#        37.62731814492387
#       ],
#       [
#        -119.0845816777264,
#        37.578880695754016
#       ],
#       [
#        -119.10422456059453,
#        37.50679275835567
#       ],
#       [
#        -119.38506342104397,
#        37.55545691568267
#       ],
#       [
#        -119.36843892592249,
#        37.61702768280726
#       ],
#       [
#        -119.36796008804473,
#        37.616944650255036
#       ],
#       [
#        -119.36518979952596,
#        37.62731814492387
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20180818_181300_1044",
#    "properties": {
#     "acquired": "2018-08-18T18:13:00.69986Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0.01,
#     "columns": 8869,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 3.8,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "origin_x": 289323,
#     "origin_y": 4167099,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2018-08-18T20:38:57Z",
#     "quality_category": "standard",
#     "rows": 4642,
#     "satellite_id": "1044",
#     "strip_id": "1638770",
#     "sun_azimuth": 128.5,
#     "sun_elevation": 55.6,
#     "updated": "2018-12-18T21:08:12Z",
#     "usable_data": 0,
#     "view_angle": 0.1
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180818_181255_1044",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180818_181255_1044/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20180818_181255_1044/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -119.0147747513043,
#        37.8351909777376
#       ],
#       [
#        -119.29675817894953,
#        37.884069268324254
#       ],
#       [
#        -119.27671860640095,
#        37.95597198863191
#       ],
#       [
#        -118.99470978451721,
#        37.90723759521878
#       ],
#       [
#        -118.99765039538444,
#        37.89684201640195
#       ],
#       [
#        -118.99741911923515,
#        37.89680198042874
#       ],
#       [
#        -119.0147747513043,
#        37.8351909777376
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20180818_181255_1044",
#    "properties": {
#     "acquired": "2018-08-18T18:12:55.47428Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0,
#     "columns": 8874,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 3.8,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "origin_x": 298020,
#     "origin_y": 4203378,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2018-08-18T20:38:57Z",
#     "quality_category": "standard",
#     "rows": 4646,
#     "satellite_id": "1044",
#     "strip_id": "1638770",
#     "sun_azimuth": 129,
#     "sun_elevation": 55.5,
#     "updated": "2018-12-18T20:43:11Z",
#     "usable_data": 0,
#     "view_angle": 0
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180818_181254_1044",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180818_181254_1044/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20180818_181254_1044/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -119.26535312331339,
#        37.99990629023081
#       ],
#       [
#        -119.26210786845856,
#        38.01170678139916
#       ],
#       [
#        -119.26186450117567,
#        38.01166469726451
#       ],
#       [
#        -119.25912050952398,
#        38.02186985073617
#       ],
#       [
#        -118.97638649616854,
#        37.972989284481315
#       ],
#       [
#        -118.97744309152027,
#        37.9691549152121
#       ],
#       [
#        -118.97923739971289,
#        37.96279158312202
#       ],
#       [
#        -118.97919842287612,
#        37.96278484307698
#       ],
#       [
#        -118.98678666333412,
#        37.935247228064874
#       ],
#       [
#        -118.99649723721627,
#        37.90091863420918
#       ],
#       [
#        -119.27886509640264,
#        37.94978971246895
#       ],
#       [
#        -119.26535312331339,
#        37.99990629023081
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20180818_181254_1044",
#    "properties": {
#     "acquired": "2018-08-18T18:12:54.42885Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0,
#     "columns": 8879,
#     "epsg_code": 32611,
#     "ground_control": true,
#     "gsd": 3.8,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "origin_x": 299772,
#     "origin_y": 4210653,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2018-08-18T20:38:57Z",
#     "quality_category": "standard",
#     "rows": 4651,
#     "satellite_id": "1044",
#     "strip_id": "1638770",
#     "sun_azimuth": 129.1,
#     "sun_elevation": 55.5,
#     "updated": "2018-12-18T21:27:54Z",
#     "usable_data": 0,
#     "view_angle": 0.1
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180818_181733_1006",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180818_181733_1006/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20180818_181733_1006/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -120.43471087956087,
#        37.62726025090001
#       ],
#       [
#        -120.43039382477203,
#        37.64276043231131
#       ],
#       [
#        -120.1509444901529,
#        37.593804877806164
#       ],
#       [
#        -120.15366402151061,
#        37.58418138756969
#       ],
#       [
#        -120.15344226757689,
#        37.58414259435528
#       ],
#       [
#        -120.17048957020381,
#        37.521656267854524
#       ],
#       [
#        -120.45000185149762,
#        37.570558601743656
#       ],
#       [
#        -120.43464497099956,
#        37.6272487431536
#       ],
#       [
#        -120.43471087956087,
#        37.62726025090001
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20180818_181733_1006",
#    "properties": {
#     "acquired": "2018-08-18T18:17:33.358413Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0.01,
#     "columns": 8781,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.8,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "origin_x": 725199,
#     "origin_y": 4169286,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2018-08-18T20:38:07Z",
#     "quality_category": "standard",
#     "rows": 4260,
#     "satellite_id": "1006",
#     "strip_id": "1638776",
#     "sun_azimuth": 128.6,
#     "sun_elevation": 55.6,
#     "updated": "2018-12-18T23:11:13Z",
#     "usable_data": 0,
#     "view_angle": 0.8
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/REOrthoTile/items/20180817_184759_1156207_RapidEye-4",
#     "assets": "https://api.planet.com/data/v1/item-types/REOrthoTile/items/20180817_184759_1156207_RapidEye-4/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/REOrthoTile/items/20180817_184759_1156207_RapidEye-4/thumb"
#    },
#    "_permissions": [
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -119.1714435,
#        37.2832025
#       ],
#       [
#        -118.8895883,
#        37.2880397
#       ],
#       [
#        -118.8839862,
#        37.0628087
#       ],
#       [
#        -119.165007,
#        37.0580106
#       ],
#       [
#        -119.1714435,
#        37.2832025
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20180817_184759_1156207_RapidEye-4",
#    "properties": {
#     "acquired": "2018-08-17T18:47:59Z",
#     "anomalous_pixels": 0.16,
#     "black_fill": 0,
#     "catalog_id": "37059195",
#     "cloud_cover": 0.16,
#     "columns": 5000,
#     "epsg_code": 32611,
#     "grid_cell": "1156207",
#     "ground_control": true,
#     "gsd": 6.5,
#     "item_type": "REOrthoTile",
#     "origin_x": 307500,
#     "origin_y": 4128500,
#     "pixel_resolution": 5,
#     "provider": "rapideye",
#     "published": "2018-08-18T15:35:07Z",
#     "rows": 5000,
#     "satellite_id": "RapidEye-4",
#     "strip_id": "37059120",
#     "sun_azimuth": 141.12142,
#     "sun_elevation": 61.30349,
#     "updated": "2018-08-18T15:35:07Z",
#     "usable_data": 0.84,
#     "view_angle": -9.86714
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/REOrthoTile/items/20180817_184802_1056226_RapidEye-4",
#     "assets": "https://api.planet.com/data/v1/item-types/REOrthoTile/items/20180817_184802_1056226_RapidEye-4/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/REOrthoTile/items/20180817_184802_1056226_RapidEye-4/thumb"
#    },
#    "_permissions": [
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -119.74783559306196,
#        37.24613580918024
#       ],
#       [
#        -119.7562574,
#        37.0336947
#       ],
#       [
#        -119.81016870015574,
#        37.03505000703211
#       ],
#       [
#        -119.755447596057,
#        37.2204697244015
#       ],
#       [
#        -119.74783559306196,
#        37.24613580918024
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20180817_184802_1056226_RapidEye-4",
#    "properties": {
#     "acquired": "2018-08-17T18:48:02Z",
#     "anomalous_pixels": 0.92,
#     "black_fill": 0.91,
#     "catalog_id": "37059175",
#     "cloud_cover": 0.01,
#     "columns": 5000,
#     "epsg_code": 32610,
#     "grid_cell": "1056226",
#     "ground_control": true,
#     "gsd": 6.5,
#     "item_type": "REOrthoTile",
#     "origin_x": 763500,
#     "origin_y": 4128500,
#     "pixel_resolution": 5,
#     "provider": "rapideye",
#     "published": "2018-08-18T15:34:53Z",
#     "rows": 5000,
#     "satellite_id": "RapidEye-4",
#     "strip_id": "37059120",
#     "sun_azimuth": 139.62719,
#     "sun_elevation": 60.88581,
#     "updated": "2018-08-18T15:34:53Z",
#     "usable_data": 0.08,
#     "view_angle": -9.86714
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/REOrthoTile/items/20180817_184801_1156205_RapidEye-4",
#     "assets": "https://api.planet.com/data/v1/item-types/REOrthoTile/items/20180817_184801_1156205_RapidEye-4/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/REOrthoTile/items/20180817_184801_1156205_RapidEye-4/thumb"
#    },
#    "_permissions": [
#     "assets.analytic:download",
#     "assets.visual:download",
#     "assets.analytic_xml:download",
#     "assets.visual_xml:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -119.7123966,
#        37.2720369
#       ],
#       [
#        -119.4306872,
#        37.2781608
#       ],
#       [
#        -119.423483,
#        37.0530089
#       ],
#       [
#        -119.7043592,
#        37.0469348
#       ],
#       [
#        -119.7123966,
#        37.2720369
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20180817_184801_1156205_RapidEye-4",
#    "properties": {
#     "acquired": "2018-08-17T18:48:01Z",
#     "anomalous_pixels": 0,
#     "black_fill": 0,
#     "catalog_id": "37059192",
#     "cloud_cover": 0,
#     "columns": 5000,
#     "epsg_code": 32611,
#     "grid_cell": "1156205",
#     "ground_control": true,
#     "gsd": 6.5,
#     "item_type": "REOrthoTile",
#     "origin_x": 259500,
#     "origin_y": 4128500,
#     "pixel_resolution": 5,
#     "provider": "rapideye",
#     "published": "2018-08-18T15:34:45Z",
#     "rows": 5000,
#     "satellite_id": "RapidEye-4",
#     "strip_id": "37059120",
#     "sun_azimuth": 140.18813,
#     "sun_elevation": 61.04094,
#     "updated": "2018-08-18T15:34:45Z",
#     "usable_data": 1,
#     "view_angle": -9.86714
#    },
#    "type": "Feature"
#   }
#  ],
#  "type": "FeatureCollection"
# }

# %%
# extract image IDs only
image_ids = [feature['id'] for feature in search_result.json()['features']]
print(image_ids)
# Out:
# ['1616849_1156605_2018-08-08_1105', '1616849_1156606_2018-08-08_1105', '1616849_1156506_2018-08-08_1105', '1616849_1156607_2018-08-08_1105', '1616849_1156105_2018-08-08_1105', '1616849_1156206_2018-08-08_1105', '1616849_1156205_2018-08-08_1105', '1616849_1156204_2018-08-08_1105', '1616849_1156306_2018-08-08_1105', '1616849_1156305_2018-08-08_1105', '1616849_1156505_2018-08-08_1105', '1616849_1156406_2018-08-08_1105', '1616849_1156706_2018-08-08_1105', '1616849_1156405_2018-08-08_1105', '1587955_1156606_2018-07-25_1105', '1587955_1156405_2018-07-25_1105', '1587955_1156406_2018-07-25_1105', '1587955_1156507_2018-07-25_1105', '1587955_1156506_2018-07-25_1105', '1587955_1156205_2018-07-25_1105', '1587955_1156607_2018-07-25_1105', '1587955_1156106_2018-07-25_1105', '1587955_1156105_2018-07-25_1105', '1587955_1156206_2018-07-25_1105', '1587955_1156306_2018-07-25_1105', '1587955_1156305_2018-07-25_1105', '1587955_1156505_2018-07-25_1105', '20180808_180612_1105', '20180808_180605_1105', '20180808_180604_1105', '20180808_180616_1105', '20180808_180614_1105', '20180808_180601_1105', '20180808_180610_1105', '20180808_180607_1105', '20180808_180611_1105', '20180808_180602_1105', '20180808_180613_1105', '20180808_180558_1105', '20180808_180603_1105', '20180808_180600_1105', '20180808_180608_1105', '20180808_180559_1105', '20180808_180615_1105', '20180808_180606_1105', '20180725_180454_1105', '20180725_180501_1105', '20180725_180450_1105', '20180725_180444_1105', '20180725_180500_1105', '20180725_180456_1105', '20180725_180452_1105', '20180725_180447_1105', '20180725_180459_1105', '20180725_180453_1105', '20180725_180457_1105', '20180725_180448_1105', '20180725_180449_1105', '20180725_180458_1105', '20180725_180502_1105', '20180725_180445_1105', '20180725_180451_1105', '20180725_180446_1105', 'S2A_MSIL1C_20180813T184921_N0206_R113_T10SGG_20180814T000638', 'S2A_MSIL1C_20180813T184921_N0206_R113_T11SKB_20180814T000638', 'S2B_MSIL1C_20180818T184909_N0206_R113_T11SKB_20180818T235244', 'S2B_MSIL1C_20180818T184909_N0206_R113_T10SGG_20180818T235244', 'S2B_MSIL1C_20180805T184019_N0206_R070_T11SLB_20180805T223228', 'S2B_MSIL1C_20180805T184019_N0206_R070_T10SGG_20180805T223228', 'S2B_MSIL1C_20180805T184019_N0206_R070_T10SGF_20180805T223228', '20180818_180216_0f1a', '20180818_180212_0f1a', '1639726_1156308_2018-08-18_0f1a', '1639726_1156307_2018-08-18_0f1a', '1639726_1156408_2018-08-18_0f1a', '1639726_1156407_2018-08-18_0f1a', '1639726_1156508_2018-08-18_0f1a', '1639726_1156507_2018-08-18_0f1a', '20180818_180218_0f1a', '20180818_180217_0f1a', '20180818_180215_0f1a', '20180818_180214_0f1a', '20180818_180213_0f1a', '20180818_180211_0f1a', '20180818_180210_0f1a', '20180818_180209_0f1a', '1639233_1156206_2018-08-18_0f36', '1639233_1156205_2018-08-18_0f36', '1639233_1156106_2018-08-18_0f36', '1639233_1156105_2018-08-18_0f36', '1639233_1156405_2018-08-18_0f36', '1639233_1156404_2018-08-18_0f36', '1639233_1156306_2018-08-18_0f36', '1639233_1156305_2018-08-18_0f36', '1639233_1156505_2018-08-18_0f36', '1639233_1156504_2018-08-18_0f36', '1639233_1156705_2018-08-18_0f36', '1639233_1156605_2018-08-18_0f36', '1639233_1156604_2018-08-18_0f36', '1639233_1056526_2018-08-18_0f36', '1639233_1056426_2018-08-18_0f36', '1639233_1056626_2018-08-18_0f36', '20180818_180602_0f36', '20180818_180601_0f36', '20180818_180600_0f36', '20180818_180559_0f36', '20180818_180558_0f36', '20180818_180557_0f36', '20180818_180556_0f36', '20180818_180555_0f36', '20180818_180554_0f36', '20180818_180553_0f36', '20180818_180552_0f36', '20180818_180551_0f36', '20180818_180550_0f36', '20180818_180549_0f36', '20180818_180548_0f36', '20180818_180547_0f36', '20180818_180546_0f36', '20180818_180545_0f36', '20180818_180544_0f36', '20180818_181556_1040', '20180818_181150_1034', '20180818_181147_1034', '20180818_181145_1034', '20180818_181143_1034', '20180818_181141_1034', '1638770_1156206_2018-08-18_1044', '1638770_1156205_2018-08-18_1044', '1638770_1156307_2018-08-18_1044', '1638770_1156305_2018-08-18 ...

# %%
# For demo purposes, just grab the first image ID
id0 = image_ids[0]
id0_url = 'https://api.planet.com/data/v1/item-types/{}/items/{}/assets'.format(item_type, id0)

# Returns JSON metadata for assets in this ID. Learn more: planet.com/docs/reference/data-api/items-assets/#asset
result = \
  requests.get(
    id0_url,
    auth=HTTPBasicAuth(PLANET_API_KEY, '')
  )

# List of asset types available for this particular satellite image
print(result.json().keys())
# Out:
# dict_keys(['field', 'general'])

# %%
result.json()
# Out:
# {'field': {},
#  'general': [{'message': 'The requested item type does not exist.'}]}

# %% [markdown]
#  ## Activation and Downloading
#
# The Data API does not pre-generate assets, so they are not always immediately availiable to download. In order to download an asset, we first have to **activate** it.
#
# Remember, earlier we decided we wanted a color-corrected image best suited for *analytic* applications. We can check the status of the analytic asset we want to download like so:

# %%
# This is "inactive" if the "analytic" asset has not yet been activated; otherwise 'active'
print(result.json()['analytic']['status'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-cad432ae0bc0> in <module>
#       1 # This is "inactive" if the "analytic" asset has not yet been activated; otherwise 'active'
# ----> 2 print(result.json()['analytic']['status'])
#
# KeyError: 'analytic'

# %%
#activate asset for download

# Parse out useful links
links = result.json()[u"analytic"]["_links"]
self_link = links["_self"]
activation_link = links["activate"]

# Request activation of the 'analytic' asset:
activate_result = \
  requests.get(
    activation_link,
    auth=HTTPBasicAuth(PLANET_API_KEY, '')
  )

# %%
activation_status_result = \
  requests.get(
    self_link,
    auth=HTTPBasicAuth(PLANET_API_KEY, '')
  )
    
print(activation_status_result.json()["status"])
# Out:
# active

# %%
# Image can be downloaded by making a GET with your Planet API key, from here:
download_link = activation_status_result.json()["location"]
print(download_link)
# Out:
# https://api.planet.com/data/v1/download?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9..dl9Q8V_ZEHHWUeyMotZY1I0-5Og4dV7RQGrGrg5liKhBaMQOQrQ-Kdj-vo9RNBb2PVwsUn0X9JFOojRFemIoGg
