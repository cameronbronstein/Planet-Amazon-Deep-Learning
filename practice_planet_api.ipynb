# %% [markdown]
# First Imports

# %%
import json
import requests

# %% [markdown]
# API Key and URL

# %%
PLANET_API_KEY = '5dc3169d9ccd4f2f9a5d6617db785661'

# %%
# Helper function to printformatted JSON using the json module
def printer(data):
    print(json.dumps(data, indent=2))

# %% [markdown]
# Requests

# %%
URL = 'https://api.planet.com/data/v1'

session = requests.Session()

res = session.get(URL, auth = (PLANET_API_KEY, '') )

# %%
res.status_code
# Out:
# 200

# %%
res.text
# Out:
# '{"_links": {"_self": "https://api.planet.com/data/v1/", "asset-types": "https://api.planet.com/data/v1/asset-types/", "item-types": "https://api.planet.com/data/v1/item-types/", "spec": "https://api.planet.com/data/v1/spec"}}'

# %%
printer(res.json())
# Out:
# {
#   "_links": {
#     "_self": "https://api.planet.com/data/v1/",
#     "asset-types": "https://api.planet.com/data/v1/asset-types/",
#     "item-types": "https://api.planet.com/data/v1/item-types/",
#     "spec": "https://api.planet.com/data/v1/spec"
#   }
# }

# %%
print(res.json()["_links"]["item-types"])
# Out:
# https://api.planet.com/data/v1/item-types/

# %% [markdown]
# Statistics endpoint

# %%
stats_url = "{}/stats".format(URL)
print(stats_url)
# Out:
# https://api.planet.com/data/v1/stats

# %% [markdown]
# **Filter Criteria:**
# - Type (type) - The type of filter being used
# - Configuration (config) - The configuration for this filter
# - Field Name (field_name) - The field on which to filter

# %%
#Specify the sensors/satellites or "item types" to include in our results
item_types = ["PSScene3Band", "REOrthoTile"]

# %%
# Create filter object for all imagery captured between 2013-01-01 and present.
date_filter = {
    "type": "DateRangeFilter", # Type of filter -> Date Range
    "field_name": "acquired", # The field to filter on: "acquired" -> Date on which the "image was taken"
    "config": {
        "gte": "2013-01-01T00:00:00.000Z", # "gte" -> Greater than or equal to
    }
}

# %%
# Construct the request.
request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : date_filter
}

# Send the POST request to the API stats endpoint
res = session.post(stats_url, json=request)

# Print response
printer(res.json())
# Out:
# {
#   "utc_offset": "+0h",
#   "interval": "year",
#   "buckets": [
#     {
#       "count": 3095020,
#       "start_time": "2013-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 3596278,
#       "start_time": "2014-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 8491790,
#       "start_time": "2015-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 37679317,
#       "start_time": "2016-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 174726781,
#       "start_time": "2017-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 241845271,
#       "start_time": "2018-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 7098906,
#       "start_time": "2019-01-01T00:00:00.000000Z"
#     }
#   ]
# }

# %% [markdown]
# Practice Exercise

# %%
# Fill in this filter to complete the exercise! 
date_filter2 = {
    'type': 'DateRangeFilter',
    'field_name': 'acquired',
    'config': {
        'lte': "2013-01-01T00:00:00.000Z"
    }
}

request = {
    "item_types" : item_types,
    "interval" : "year",
    "filter" : date_filter
}

res = session.post(stats_url, json=request)
printer(res.json())
# Out:
# {
#   "utc_offset": "+0h",
#   "interval": "year",
#   "buckets": [
#     {
#       "count": 3095020,
#       "start_time": "2013-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 3596278,
#       "start_time": "2014-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 8491790,
#       "start_time": "2015-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 37679317,
#       "start_time": "2016-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 174726781,
#       "start_time": "2017-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 241845271,
#       "start_time": "2018-01-01T00:00:00.000000Z"
#     },
#     {
#       "count": 7098906,
#       "start_time": "2019-01-01T00:00:00.000000Z"
#     }
#   ]
# }

# %% [markdown]
# **Field Filters**
# - DateRangeFilter
# - RangeFilter
# - StringInFilter
# - PermissionFilter
# - GeometryFilter
#
# **Logical Filters**
# - NotFilter
# - AndFilter
# - OrFilter

# %% [markdown]
# **Camp Fire Dates:**
#
# Began: 2018-11-08
#
# Contained: 2018-11-25
#
# End buring: 2018-??-??

# %%
camp_fire_filter = {  
   "type":"AndFilter",
   "config":[  
      {  
         "type":"DateRangeFilter",
         "field_name":"acquired",
         "config":{  
            "gte":"2018-11-01T00:00:00Z",
            "lte":"2018-12-01T00:00:00Z"
         }
      },
      {  
         "type":"GeometryFilter",
         "field_name":"geometry",
         "config":{"type":"Polygon",
                   "coordinates": [
          [
            [
              -122.11166381835936,
              39.977120098439634
            ],
            [
              -122.0745849609375,
              39.48814483559126
            ],
            [
              -121.09268188476562,
              39.54641191968671
            ],
            [
              -121.12976074218749,
              39.985538414809746
            ],
            [
              -122.11166381835936,
              39.977120098439634
            ]
          ]
        ]
                  }
      }
    ]
}

# %%
request = {
    "item_types" : item_types,
    "interval" : "day",
    "filter" : camp_fire_filter
}

res = session.post(stats_url, json=request)
printer(res.json())
# Out:
# {
#   "utc_offset": "+0h",
#   "interval": "day",
#   "buckets": [
#     {
#       "count": 46,
#       "start_time": "2018-11-01T00:00:00.000000Z"
#     },
#     {
#       "count": 44,
#       "start_time": "2018-11-02T00:00:00.000000Z"
#     },
#     {
#       "count": 51,
#       "start_time": "2018-11-03T00:00:00.000000Z"
#     },
#     {
#       "count": 64,
#       "start_time": "2018-11-04T00:00:00.000000Z"
#     },
#     {
#       "count": 55,
#       "start_time": "2018-11-05T00:00:00.000000Z"
#     },
#     {
#       "count": 63,
#       "start_time": "2018-11-06T00:00:00.000000Z"
#     },
#     {
#       "count": 41,
#       "start_time": "2018-11-07T00:00:00.000000Z"
#     },
#     {
#       "count": 38,
#       "start_time": "2018-11-08T00:00:00.000000Z"
#     },
#     {
#       "count": 49,
#       "start_time": "2018-11-09T00:00:00.000000Z"
#     },
#     {
#       "count": 50,
#       "start_time": "2018-11-10T00:00:00.000000Z"
#     },
#     {
#       "count": 60,
#       "start_time": "2018-11-11T00:00:00.000000Z"
#     },
#     {
#       "count": 34,
#       "start_time": "2018-11-12T00:00:00.000000Z"
#     },
#     {
#       "count": 62,
#       "start_time": "2018-11-13T00:00:00.000000Z"
#     },
#     {
#       "count": 75,
#       "start_time": "2018-11-14T00:00:00.000000Z"
#     },
#     {
#       "count": 53,
#       "start_time": "2018-11-15T00:00:00.000000Z"
#     },
#     {
#       "count": 42,
#       "start_time": "2018-11-16T00:00:00.000000Z"
#     },
#     {
#       "count": 65,
#       "start_time": "2018-11-17T00:00:00.000000Z"
#     },
#     {
#       "count": 65,
#       "start_time": "2018-11-18T00:00:00.000000Z"
#     },
#     {
#       "count": 51,
#       "start_time": "2018-11-19T00:00:00.000000Z"
#     },
#     {
#       "count": 28,
#       "start_time": "2018-11-20T00:00:00.000000Z"
#     },
#     {
#       "count": 40,
#       "start_time": "2018-11-21T00:00:00.000000Z"
#     },
#     {
#       "count": 82,
#       "start_time": "2018-11-22T00:00:00.000000Z"
#     },
#     {
#       "count": 45,
#       "start_time": "2018-11-23T00:00:00.000000Z"
#     },
#     {
#       "count": 36,
#       "start_time": "2018-11-24T00:00:00.000000Z"
#     },
#     {
#       "count": 46,
#       "start_time": "2018-11-25T00:00:00.000000Z"
#     },
#     {
#       "count": 47,
#       "start_time": "2018-11-26T00:00:00.000000Z"
#     },
#     {
#       "count": 35,
#       "start_time": "2018-11-27T00:00:00.000000Z"
#     },
#     {
#       "count": 36,
#       "start_time": "2018-11-28T00:00:00.000000Z"
#     },
#     {
#       "count": 42,
#       "start_time": "2018-11-29T00:00:00.000000Z"
#     },
#     {
#       "count": 63,
#       "start_time": "2018-11-30T00:00:00.000000Z"
#     }
#   ]
# }

# %%
date_filter = {"type":"DateRangeFilter", 
               "field_name":"acquired", 
               "config":{"gte":"2018-11-01T00:00:00Z",
                         "lte":"2018-12-01T00:00:00Z"
                        }
              }

geo_filter = {"type":"GeometryFilter", 
              "field_name":"geometry", 
              "config":{"type":"Polygon",
                        "coordinates": [
                            [
                                        [
                                          -122.11166381835936,
                                          39.977120098439634
                                        ],
                                        [
                                          -122.0745849609375,
                                          39.48814483559126
                                        ],
                                        [
                                          -121.09268188476562,
                                          39.54641191968671
                                        ],
                                        [
                                          -121.12976074218749,
                                          39.985538414809746
                                        ],
                                        [
                                          -122.11166381835936,
                                          39.977120098439634
                                        ]
                                      ]
                        ]
                       }
             }

# %%
camp_filter = {"type":"AndFilter",
               "config":[date_filter, geo_filter]}

request = {
    "item_types" : item_types,
    "interval" : "month",
    "filter" : camp_filter 
}

res = session.post(stats_url, json=request)
printer(res.json())
# Out:
# {
#   "utc_offset": "+0h",
#   "interval": "month",
#   "buckets": [
#     {
#       "count": 1508,
#       "start_time": "2018-11-01T00:00:00.000000Z"
#     }
#   ]
# }

# %%
camp_fire_filter = {  
   "type":"AndFilter",
   "config":[  
      {  
         "type":"DateRangeFilter",
         "field_name":"acquired",
         "config":{  
            "gte":"2018-11-01T00:00:00Z",
            "lte":"2018-12-01T00:00:00Z"
         }
      },
      {  
         "type":"GeometryFilter",
         "field_name":"geometry",
         "config":{"type":"Polygon",
                   "coordinates": [
          [
            [
              -122.11166381835936,
              39.977120098439634
            ],
            [
              -122.0745849609375,
              39.48814483559126
            ],
            [
              -121.09268188476562,
              39.54641191968671
            ],
            [
              -121.12976074218749,
              39.985538414809746
            ],
            [
              -122.11166381835936,
              39.977120098439634
            ]
          ]
        ]
                  }
      }
    ]
}

# %% [markdown]
# ### Ferguson Fire Coordinates

# %%
ferguson_fire = {
    "type": "Polygon",
    "coordinates": [
        [
            [
              -120.39916992187499,
              37.58158917213053
            ],
            [
              -119.49554443359376,
              36.98280911070616
            ],
            [
              -118.67156982421875,
              37.58376576718623
            ],
            [
              -119.4873046875,
              38.20581359813473
            ],
            [
              -120.39916992187499,
              37.58158917213053
            ]
          ]
    ]
}

# %% [markdown]
# ### Woolesly Fire

# %%
woolesly_fire = {"type": "Polygon", 
                 "coordinates": [
                 [
                  -119.036865234375,
                  33.99575015925125
                 ],
                 [
                  -118.54522705078126,
                  33.99802726234877
                 ],
                 [
                  -118.54248046874999,
                  34.3955786154917
                 ],
                 [
                  -119.04235839843749,
                  34.40464357107094
                 ],
                 [
                  -119.04373168945314,
                  33.99916579100914
                 ]
            ] 
        }

# %% [markdown]
# #### Quick Search

# %%
# Setup the quick search endpoint url
quick_url = "{}/quick-search".format(URL)

# %%
from requests.auth import HTTPBasicAuth


# API Key stored as an env variable
PLANET_API_KEY = '5dc3169d9ccd4f2f9a5d6617db785661'

item_type = "PSScene4Band"

# API request object
search_request = {
  "interval": "day",
  "item_types": [item_type], 
  "filter": camp_fire_filter
}

# fire off the POST request
search_result = \
  requests.post(
    'https://api.planet.com/data/v1/quick-search',
    auth=HTTPBasicAuth(PLANET_API_KEY, ''),
    json=search_request)

print(json.dumps(search_result.json(), indent=1))
# Out:
# {
#  "_links": {
#   "_first": "https://api.planet.com/data/v1/searches/36ccccf6f2f6494e8b7abe63e21e235a/results?_page=eyJxdWVyeV9wYXJhbXMiOiB7fSwgInNvcnRfcHJldiI6IGZhbHNlLCAicGFnZV9zaXplIjogMjUwLCAic29ydF9ieSI6ICJwdWJsaXNoZWQiLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9kZXNjIjogdHJ1ZX0%3D",
#   "_next": "https://api.planet.com/data/v1/searches/36ccccf6f2f6494e8b7abe63e21e235a/results?_page=eyJxdWVyeV9wYXJhbXMiOiB7fSwgInNvcnRfcHJldiI6IGZhbHNlLCAicGFnZV9zaXplIjogMjUwLCAic29ydF9ieSI6ICJwdWJsaXNoZWQiLCAic29ydF9zdGFydCI6ICIyMDE4LTExLTIwVDIyOjAzOjE0LjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMTgxMTIwXzE4MjgwNl8xMDA4IiwgInNvcnRfZGVzYyI6IHRydWV9",
#   "_self": "https://api.planet.com/data/v1/searches/36ccccf6f2f6494e8b7abe63e21e235a/results?_page=eyJxdWVyeV9wYXJhbXMiOiB7fSwgInNvcnRfcHJldiI6IGZhbHNlLCAicGFnZV9zaXplIjogMjUwLCAic29ydF9ieSI6ICJwdWJsaXNoZWQiLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9kZXNjIjogdHJ1ZX0%3D"
#  },
#  "features": [
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_180019_1043",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_180019_1043/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20181130_180019_1043/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -122.05969156212792,
#        39.93273063652571
#       ],
#       [
#        -122.33610604159632,
#        39.889401422668634
#       ],
#       [
#        -122.35400863704986,
#        39.95780376246812
#       ],
#       [
#        -122.07818003654046,
#        40.001376941604335
#       ],
#       [
#        -122.0752869242921,
#        39.990242845363134
#       ],
#       [
#        -122.07460415194504,
#        39.99034978892283
#       ],
#       [
#        -122.05969156212792,
#        39.93273063652571
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20181130_180019_1043",
#    "properties": {
#     "acquired": "2018-11-30T18:00:19.257882Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0.23,
#     "columns": 8390,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.6,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "origin_x": 555174,
#     "origin_y": 4428318,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2018-12-01T04:04:27Z",
#     "quality_category": "standard",
#     "rows": 4209,
#     "satellite_id": "1043",
#     "strip_id": "1891440",
#     "sun_azimuth": 150.1,
#     "sun_elevation": 22.5,
#     "updated": "2018-12-01T04:10:20Z",
#     "usable_data": 0,
#     "view_angle": 5
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_180018_1043",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_180018_1043/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20181130_180018_1043/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -122.04312959044306,
#        39.87096858595036
#       ],
#       [
#        -122.31923933553398,
#        39.827658282454244
#       ],
#       [
#        -122.33718080321366,
#        39.896214749490696
#       ],
#       [
#        -122.06151597942376,
#        39.93977980635425
#       ],
#       [
#        -122.05858959244205,
#        39.92847285433989
#       ],
#       [
#        -122.05802586246769,
#        39.928561180234475
#       ],
#       [
#        -122.04312959044306,
#        39.87096858595036
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20181130_180018_1043",
#    "properties": {
#     "acquired": "2018-11-30T18:00:18.285852Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0.22,
#     "columns": 8391,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.6,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "origin_x": 556662,
#     "origin_y": 4421496,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2018-12-01T04:04:27Z",
#     "quality_category": "standard",
#     "rows": 4216,
#     "satellite_id": "1043",
#     "strip_id": "1891440",
#     "sun_azimuth": 150.1,
#     "sun_elevation": 22.6,
#     "updated": "2018-12-01T04:10:46Z",
#     "usable_data": 0,
#     "view_angle": 5
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_180017_1043",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_180017_1043/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20181130_180017_1043/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -122.02644346470093,
#        39.809443296466746
#       ],
#       [
#        -122.30241142932323,
#        39.76616687079413
#       ],
#       [
#        -122.32041408120013,
#        39.83460014225949
#       ],
#       [
#        -122.04495465109731,
#        39.87802471231744
#       ],
#       [
#        -122.04202569317917,
#        39.86670065185617
#       ],
#       [
#        -122.04133691375519,
#        39.8668086501892
#       ],
#       [
#        -122.02644346470093,
#        39.809443296466746
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20181130_180017_1043",
#    "properties": {
#     "acquired": "2018-11-30T18:00:17.313822Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0.14,
#     "columns": 8396,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.7,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "origin_x": 558147,
#     "origin_y": 4414656,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2018-12-01T04:04:27Z",
#     "quality_category": "standard",
#     "rows": 4207,
#     "satellite_id": "1043",
#     "strip_id": "1891440",
#     "sun_azimuth": 150.1,
#     "sun_elevation": 22.6,
#     "updated": "2018-12-01T04:10:12Z",
#     "usable_data": 0,
#     "view_angle": 5
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_180012_1043",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_180012_1043/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20181130_180012_1043/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -122.22835908232264,
#        39.48561495823339
#       ],
#       [
#        -122.23916714978463,
#        39.52711634422813
#       ],
#       [
#        -121.96430490549673,
#        39.57061927600914
#       ],
#       [
#        -121.96135162857593,
#        39.55914496511047
#       ],
#       [
#        -121.96123034187458,
#        39.55916399482904
#       ],
#       [
#        -121.94920971614354,
#        39.51359152737813
#       ],
#       [
#        -121.94621527125167,
#        39.50195368959417
#       ],
#       [
#        -122.2211665313173,
#        39.45874865472484
#       ],
#       [
#        -122.22835908232264,
#        39.48561495823339
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20181130_180012_1043",
#    "properties": {
#     "acquired": "2018-11-30T18:00:12.452624Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0.26,
#     "columns": 8405,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.6,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "origin_x": 565389,
#     "origin_y": 4380615,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2018-12-01T04:04:27Z",
#     "quality_category": "standard",
#     "rows": 4214,
#     "satellite_id": "1043",
#     "strip_id": "1891440",
#     "sun_azimuth": 150.1,
#     "sun_elevation": 22.9,
#     "updated": "2018-12-01T04:09:54Z",
#     "usable_data": 0,
#     "view_angle": 5
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_175422_100d",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_175422_100d/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20181130_175422_100d/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.54330608249073,
#        40.02400109362952
#       ],
#       [
#        -121.82188996374295,
#        39.97774282959913
#       ],
#       [
#        -121.84127994574358,
#        40.04664556036884
#       ],
#       [
#        -121.5633862793386,
#        40.09243461115619
#       ],
#       [
#        -121.56019499247755,
#        40.08107541805752
#       ],
#       [
#        -121.55941706504674,
#        40.08120386964223
#       ],
#       [
#        -121.558148137963,
#        40.07674153007705
#       ],
#       [
#        -121.54330608249073,
#        40.02400109362952
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20181130_175422_100d",
#    "properties": {
#     "acquired": "2018-11-30T17:54:22.119359Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0.96,
#     "columns": 8488,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.7,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "origin_x": 598839,
#     "origin_y": 4439007,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2018-12-01T02:39:52Z",
#     "quality_category": "test",
#     "rows": 4352,
#     "satellite_id": "100d",
#     "strip_id": "1891106",
#     "sun_azimuth": 150.1,
#     "sun_elevation": 22.3,
#     "updated": "2018-12-01T03:49:14Z",
#     "usable_data": 0,
#     "view_angle": 5
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_175421_100d",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_175421_100d/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20181130_175421_100d/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.80964951777284,
#        39.93529746383484
#       ],
#       [
#        -121.82353629959162,
#        39.985141837545996
#       ],
#       [
#        -121.54520123725374,
#        40.03073542294955
#       ],
#       [
#        -121.54211072552,
#        40.01975345768285
#       ],
#       [
#        -121.54194542942614,
#        40.019780918454465
#       ],
#       [
#        -121.54044849214353,
#        40.014466153803696
#       ],
#       [
#        -121.52627301654042,
#        39.96209763617213
#       ],
#       [
#        -121.80420419832863,
#        39.91620183276065
#       ],
#       [
#        -121.80964951777284,
#        39.93529746383484
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20181130_175421_100d",
#    "properties": {
#     "acquired": "2018-11-30T17:54:21.147853Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0.95,
#     "columns": 8475,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.7,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "origin_x": 600444,
#     "origin_y": 4432185,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2018-12-01T02:39:52Z",
#     "quality_category": "test",
#     "rows": 4349,
#     "satellite_id": "100d",
#     "strip_id": "1891106",
#     "sun_azimuth": 150.1,
#     "sun_elevation": 22.4,
#     "updated": "2018-12-01T03:48:29Z",
#     "usable_data": 0,
#     "view_angle": 5
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_175420_100d",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_175420_100d/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20181130_175420_100d/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.50911989225064,
#        39.90067877487511
#       ],
#       [
#        -121.78683972370251,
#        39.854730125130494
#       ],
#       [
#        -121.80624692701869,
#        39.92369348901372
#       ],
#       [
#        -121.52817828988,
#        39.969136295281054
#       ],
#       [
#        -121.52512120611138,
#        39.95784249818241
#       ],
#       [
#        -121.5248136381854,
#        39.95789330768424
#       ],
#       [
#        -121.51985793352527,
#        39.940285782971074
#       ],
#       [
#        -121.50911989225064,
#        39.90067877487511
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20181130_175420_100d",
#    "properties": {
#     "acquired": "2018-11-30T17:54:20.175823Z",
#     "anomalous_pixels": 0.01,
#     "cloud_cover": 0.93,
#     "columns": 8479,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.7,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "origin_x": 602013,
#     "origin_y": 4425369,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2018-12-01T02:39:52Z",
#     "quality_category": "test",
#     "rows": 4344,
#     "satellite_id": "100d",
#     "strip_id": "1891106",
#     "sun_azimuth": 150.1,
#     "sun_elevation": 22.4,
#     "updated": "2018-12-01T03:48:54Z",
#     "usable_data": 0,
#     "view_angle": 5
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_175419_100d",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_175419_100d/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20181130_175419_100d/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.78406164527506,
#        39.84447157475201
#       ],
#       [
#        -121.78899428394368,
#        39.86239637439945
#       ],
#       [
#        -121.51138054738773,
#        39.90796143631293
#       ],
#       [
#        -121.49189488803177,
#        39.83950215152434
#       ],
#       [
#        -121.76956610599298,
#        39.79350809280812
#       ],
#       [
#        -121.78396715513678,
#        39.84448730093466
#       ],
#       [
#        -121.78406164527506,
#        39.84447157475201
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20181130_175419_100d",
#    "properties": {
#     "acquired": "2018-11-30T17:54:19.203793Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0.93,
#     "columns": 8486,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.7,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "origin_x": 603579,
#     "origin_y": 4418604,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2018-12-01T02:39:52Z",
#     "quality_category": "test",
#     "rows": 4347,
#     "satellite_id": "100d",
#     "strip_id": "1891106",
#     "sun_azimuth": 150.1,
#     "sun_elevation": 22.5,
#     "updated": "2018-12-01T03:48:37Z",
#     "usable_data": 0,
#     "view_angle": 5
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_175418_100d",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_175418_100d/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20181130_175418_100d/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.77169341595058,
#        39.801038695335414
#       ],
#       [
#        -121.4947213309105,
#        39.84664131367892
#       ],
#       [
#        -121.47540310816875,
#        39.778137860480385
#       ],
#       [
#        -121.75254705484862,
#        39.73202016554192
#       ],
#       [
#        -121.7688163594765,
#        39.78916499141991
#       ],
#       [
#        -121.76836056992853,
#        39.789240537484886
#       ],
#       [
#        -121.77169341595058,
#        39.801038695335414
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20181130_175418_100d",
#    "properties": {
#     "acquired": "2018-11-30T17:54:18.232288Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0.83,
#     "columns": 8471,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.7,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "origin_x": 605151,
#     "origin_y": 4411821,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2018-12-01T02:39:52Z",
#     "quality_category": "test",
#     "rows": 4355,
#     "satellite_id": "100d",
#     "strip_id": "1891106",
#     "sun_azimuth": 150.1,
#     "sun_elevation": 22.5,
#     "updated": "2018-12-01T03:49:12Z",
#     "usable_data": 0,
#     "view_angle": 5
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_175417_100d",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_175417_100d/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20181130_175417_100d/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.75467901736377,
#        39.73950853886173
#       ],
#       [
#        -121.47783740951127,
#        39.78509851601718
#       ],
#       [
#        -121.45888999180966,
#        39.716445262743015
#       ],
#       [
#        -121.73572809491141,
#        39.67047259753101
#       ],
#       [
#        -121.75194851453627,
#        39.72764554197975
#       ],
#       [
#        -121.75133086467801,
#        39.72774838029213
#       ],
#       [
#        -121.75467901736377,
#        39.73950853886173
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20181130_175417_100d",
#    "properties": {
#     "acquired": "2018-11-30T17:54:17.260258Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0.75,
#     "columns": 8465,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.7,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "origin_x": 606702,
#     "origin_y": 4405014,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2018-12-01T02:39:47Z",
#     "quality_category": "test",
#     "rows": 4356,
#     "satellite_id": "100d",
#     "strip_id": "1891106",
#     "sun_azimuth": 150.1,
#     "sun_elevation": 22.6,
#     "updated": "2018-12-01T03:48:27Z",
#     "usable_data": 0,
#     "view_angle": 5.1
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_175416_100d",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_175416_100d/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20181130_175416_100d/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.72690436370982,
#        39.63814718896774
#       ],
#       [
#        -121.73472673299717,
#        39.66617161844784
#       ],
#       [
#        -121.73451773113929,
#        39.66620636630479
#       ],
#       [
#        -121.73777928832887,
#        39.67770254410591
#       ],
#       [
#        -121.4610071649701,
#        39.72361831697615
#       ],
#       [
#        -121.44793085978634,
#        39.67709816180426
#       ],
#       [
#        -121.44183866686193,
#        39.65500068072842
#       ],
#       [
#        -121.71851745129835,
#        39.608767247448036
#       ],
#       [
#        -121.72690436370982,
#        39.63814718896774
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20181130_175416_100d",
#    "properties": {
#     "acquired": "2018-11-30T17:54:16.288752Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0.64,
#     "columns": 8476,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.7,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "origin_x": 608247,
#     "origin_y": 4398216,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2018-12-01T02:39:47Z",
#     "quality_category": "test",
#     "rows": 4366,
#     "satellite_id": "100d",
#     "strip_id": "1891106",
#     "sun_azimuth": 150.1,
#     "sun_elevation": 22.7,
#     "updated": "2018-12-01T03:49:25Z",
#     "usable_data": 0,
#     "view_angle": 5.1
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_175415_100d",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_175415_100d/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20181130_175415_100d/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.71753065895786,
#        39.6053104447734
#       ],
#       [
#        -121.7206331392632,
#        39.61653778477433
#       ],
#       [
#        -121.44400759988147,
#        39.66208635928761
#       ],
#       [
#        -121.43356769887974,
#        39.624950557721974
#       ],
#       [
#        -121.42504613333736,
#        39.59345942189328
#       ],
#       [
#        -121.70119687960644,
#        39.54760369383869
#       ],
#       [
#        -121.71213302402036,
#        39.585777336846824
#       ],
#       [
#        -121.71730799478122,
#        39.6045046616028
#       ],
#       [
#        -121.7173009721158,
#        39.604505835680484
#       ],
#       [
#        -121.71753065895786,
#        39.6053104447734
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20181130_175415_100d",
#    "properties": {
#     "acquired": "2018-11-30T17:54:15.316722Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0.77,
#     "columns": 8473,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.7,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "origin_x": 609816,
#     "origin_y": 4391412,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2018-12-01T02:39:47Z",
#     "quality_category": "test",
#     "rows": 4353,
#     "satellite_id": "100d",
#     "strip_id": "1891106",
#     "sun_azimuth": 150.1,
#     "sun_elevation": 22.7,
#     "updated": "2018-12-01T03:48:19Z",
#     "usable_data": 0,
#     "view_angle": 5
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_175414_100d",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_175414_100d/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20181130_175414_100d/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.70338653507493,
#        39.55524689266648
#       ],
#       [
#        -121.42721711839268,
#        39.60061127209659
#       ],
#       [
#        -121.40797134319054,
#        39.53216039058222
#       ],
#       [
#        -121.68422212089844,
#        39.486344353577245
#       ],
#       [
#        -121.70037246649933,
#        39.54327004671161
#       ],
#       [
#        -121.6999742864416,
#        39.54333611714508
#       ],
#       [
#        -121.70338653507493,
#        39.55524689266648
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20181130_175414_100d",
#    "properties": {
#     "acquired": "2018-11-30T17:54:14.344692Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0.81,
#     "columns": 8476,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.7,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "origin_x": 611394,
#     "origin_y": 4384614,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2018-12-01T02:39:47Z",
#     "quality_category": "test",
#     "rows": 4347,
#     "satellite_id": "100d",
#     "strip_id": "1891106",
#     "sun_azimuth": 150.1,
#     "sun_elevation": 22.8,
#     "updated": "2018-12-01T03:49:23Z",
#     "usable_data": 0,
#     "view_angle": 5.1
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_175413_100d",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_175413_100d/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20181130_175413_100d/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.68637248749357,
#        39.49392382660812
#       ],
#       [
#        -121.41073503520425,
#        39.53924101517087
#       ],
#       [
#        -121.39132724705998,
#        39.470772250881545
#       ],
#       [
#        -121.66716668572356,
#        39.42502425345797
#       ],
#       [
#        -121.68343047501779,
#        39.48201349757992
#       ],
#       [
#        -121.68301306812185,
#        39.482082762584476
#       ],
#       [
#        -121.68637248749357,
#        39.49392382660812
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20181130_175413_100d",
#    "properties": {
#     "acquired": "2018-11-30T17:54:13.373186Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0.97,
#     "columns": 8474,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.7,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "origin_x": 612954,
#     "origin_y": 4377828,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2018-12-01T02:39:41Z",
#     "quality_category": "test",
#     "rows": 4346,
#     "satellite_id": "100d",
#     "strip_id": "1891106",
#     "sun_azimuth": 150.1,
#     "sun_elevation": 22.8,
#     "updated": "2018-12-01T03:48:30Z",
#     "usable_data": 0,
#     "view_angle": 5
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_180016_1043",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_180016_1043/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20181130_180016_1043/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -122.29003379237439,
#        39.72018700523291
#       ],
#       [
#        -122.30387050522054,
#        39.77316534376287
#       ],
#       [
#        -122.02834547519097,
#        39.81676930296445
#       ],
#       [
#        -122.02533994983541,
#        39.805192869291155
#       ],
#       [
#        -122.02502631799004,
#        39.80524200499056
#       ],
#       [
#        -122.02254824171051,
#        39.79596423806092
#       ],
#       [
#        -122.01026327527772,
#        39.748037630656334
#       ],
#       [
#        -122.28586258737185,
#        39.704734463072484
#       ],
#       [
#        -122.29003379237439,
#        39.72018700523291
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20181130_180016_1043",
#    "properties": {
#     "acquired": "2018-11-30T18:00:16.341268Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0.52,
#     "columns": 8393,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.6,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "origin_x": 559617,
#     "origin_y": 4407873,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2018-12-01T02:05:08Z",
#     "quality_category": "standard",
#     "rows": 4215,
#     "satellite_id": "1043",
#     "strip_id": "1891440",
#     "sun_azimuth": 150.1,
#     "sun_elevation": 22.7,
#     "updated": "2018-12-01T04:31:28Z",
#     "usable_data": 0,
#     "view_angle": 5
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_180015_1043",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_180015_1043/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20181130_180015_1043/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -122.00913912475797,
#        39.74378016661654
#       ],
#       [
#        -121.99390671798692,
#        39.68654957253177
#       ],
#       [
#        -122.2694834579994,
#        39.64323518500074
#       ],
#       [
#        -122.28487379185788,
#        39.70048078992207
#       ],
#       [
#        -122.28472084885092,
#        39.700504806985066
#       ],
#       [
#        -122.28772215248519,
#        39.71162336167526
#       ],
#       [
#        -122.01220314142368,
#        39.75529216840987
#       ],
#       [
#        -122.0100283342309,
#        39.74712106915196
#       ],
#       [
#        -122.00917069419215,
#        39.74377520918105
#       ],
#       [
#        -122.00913912475797,
#        39.74378016661654
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20181130_180015_1043",
#    "properties": {
#     "acquired": "2018-11-30T18:00:15.369238Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0.65,
#     "columns": 8407,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.6,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "origin_x": 561054,
#     "origin_y": 4401066,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2018-12-01T02:05:08Z",
#     "quality_category": "standard",
#     "rows": 4217,
#     "satellite_id": "1043",
#     "strip_id": "1891440",
#     "sun_azimuth": 150.1,
#     "sun_elevation": 22.7,
#     "updated": "2018-12-01T04:31:36Z",
#     "usable_data": 0,
#     "view_angle": 5
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_180014_1043",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_180014_1043/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20181130_180014_1043/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -122.27133527690673,
#        39.65012317680973
#       ],
#       [
#        -121.99656257855561,
#        39.69362147451105
#       ],
#       [
#        -121.97830907641874,
#        39.62494313308841
#       ],
#       [
#        -122.25337035943767,
#        39.58173668581097
#       ],
#       [
#        -122.26876142158557,
#        39.63893541359856
#       ],
#       [
#        -122.26834506065917,
#        39.639000823031644
#       ],
#       [
#        -122.27133527690673,
#        39.65012317680973
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20181130_180014_1043",
#    "properties": {
#     "acquired": "2018-11-30T18:00:14.397208Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0.46,
#     "columns": 8391,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.6,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "origin_x": 562515,
#     "origin_y": 4394235,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2018-12-01T02:05:08Z",
#     "quality_category": "standard",
#     "rows": 4212,
#     "satellite_id": "1043",
#     "strip_id": "1891440",
#     "sun_azimuth": 150.1,
#     "sun_elevation": 22.8,
#     "updated": "2018-12-01T04:32:01Z",
#     "usable_data": 0,
#     "view_angle": 5
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_180013_1043",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_180013_1043/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20181130_180013_1043/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.96244850686324,
#        39.56340664555026
#       ],
#       [
#        -122.23760501713829,
#        39.52021367541136
#       ],
#       [
#        -122.25250723066203,
#        39.577461553626186
#       ],
#       [
#        -122.2522316471336,
#        39.57750482094789
#       ],
#       [
#        -122.25524073008752,
#        39.58868765648698
#       ],
#       [
#        -121.98030945745731,
#        39.63219145973035
#       ],
#       [
#        -121.97517839894867,
#        39.61286585422316
#       ],
#       [
#        -121.96244850686324,
#        39.56340664555026
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20181130_180013_1043",
#    "properties": {
#     "acquired": "2018-11-30T18:00:13.424654Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0.35,
#     "columns": 8392,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.6,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "origin_x": 563952,
#     "origin_y": 4387434,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2018-12-01T02:05:07Z",
#     "quality_category": "standard",
#     "rows": 4217,
#     "satellite_id": "1043",
#     "strip_id": "1891440",
#     "sun_azimuth": 150.1,
#     "sun_elevation": 22.9,
#     "updated": "2018-12-01T04:32:25Z",
#     "usable_data": 0,
#     "view_angle": 5
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_180011_1043",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181130_180011_1043/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20181130_180011_1043/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -122.21737040160934,
#        39.44378553030575
#       ],
#       [
#        -122.22015078971299,
#        39.45450054425817
#       ],
#       [
#        -122.22003414710645,
#        39.45451886506131
#       ],
#       [
#        -122.22299576831854,
#        39.465581395490666
#       ],
#       [
#        -121.94847523121851,
#        39.509133791918785
#       ],
#       [
#        -121.93434230879949,
#        39.45587509988659
#       ],
#       [
#        -121.93038114240726,
#        39.44038220482114
#       ],
#       [
#        -122.20488119304608,
#        39.397151504488484
#       ],
#       [
#        -122.21737040160934,
#        39.44378553030575
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20181130_180011_1043",
#    "properties": {
#     "acquired": "2018-11-30T18:00:11.480594Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0.29,
# ...
#       ],
#       [
#        -121.69073162555303,
#        39.53363448215532
#       ],
#       [
#        -121.69054048783178,
#        39.5336020129114
#       ],
#       [
#        -121.70795604888107,
#        39.473461012517774
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20181120_182812_1008",
#    "properties": {
#     "acquired": "2018-11-20T18:28:12.613817Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0.21,
#     "columns": 8917,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.9,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "origin_x": 586062,
#     "origin_y": 4383387,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2018-11-20T22:03:15Z",
#     "quality_category": "standard",
#     "rows": 4424,
#     "satellite_id": "1008",
#     "strip_id": "1863787",
#     "sun_azimuth": 157.4,
#     "sun_elevation": 27.5,
#     "updated": "2018-11-21T04:08:18Z",
#     "usable_data": 0,
#     "view_angle": 0.1
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181120_182811_1008",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181120_182811_1008/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20181120_182811_1008/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.96079990220379,
#        39.657455207258906
#       ],
#       [
#        -121.95984496658149,
#        39.66079636012484
#       ],
#       [
#        -121.66859782076459,
#        39.611262469883144
#       ],
#       [
#        -121.68239917282645,
#        39.56237754188516
#       ],
#       [
#        -121.68932621380516,
#        39.53848249451608
#       ],
#       [
#        -121.9803723049966,
#        39.587926090627654
#       ],
#       [
#        -121.97021174123293,
#        39.62452482722947
#       ],
#       [
#        -121.96343788880264,
#        39.64822535314178
#       ],
#       [
#        -121.96337344351052,
#        39.648214405744135
#       ],
#       [
#        -121.96079990220379,
#        39.657455207258906
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20181120_182811_1008",
#    "properties": {
#     "acquired": "2018-11-20T18:28:11.571532Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0.5,
#     "columns": 8912,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.9,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "origin_x": 587556,
#     "origin_y": 4390629,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2018-11-20T22:03:15Z",
#     "quality_category": "standard",
#     "rows": 4425,
#     "satellite_id": "1008",
#     "strip_id": "1863787",
#     "sun_azimuth": 157.4,
#     "sun_elevation": 27.5,
#     "updated": "2018-11-21T04:08:00Z",
#     "usable_data": 0,
#     "view_angle": 0.1
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181120_182810_1008",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181120_182810_1008/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20181120_182810_1008/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.95303770047667,
#        39.68532690502031
#       ],
#       [
#        -121.94141432203685,
#        39.72595390722227
#       ],
#       [
#        -121.65030676135152,
#        39.676391468270594
#       ],
#       [
#        -121.65382909920758,
#        39.664206399405494
#       ],
#       [
#        -121.65339476519632,
#        39.66413263982507
#       ],
#       [
#        -121.66509777567575,
#        39.62263411448131
#       ],
#       [
#        -121.67060795581389,
#        39.60356958900758
#       ],
#       [
#        -121.962019565419,
#        39.65307576883403
#       ],
#       [
#        -121.95303770047667,
#        39.68532690502031
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20181120_182810_1008",
#    "properties": {
#     "acquired": "2018-11-20T18:28:10.529248Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0.56,
#     "columns": 8903,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.9,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "origin_x": 589047,
#     "origin_y": 4397880,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2018-11-20T22:03:15Z",
#     "quality_category": "standard",
#     "rows": 4426,
#     "satellite_id": "1008",
#     "strip_id": "1863787",
#     "sun_azimuth": 157.5,
#     "sun_elevation": 27.4,
#     "updated": "2018-11-21T04:08:30Z",
#     "usable_data": 0,
#     "view_angle": 0.1
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181120_182809_1008",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181120_182809_1008/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20181120_182809_1008/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.6524265964997,
#        39.66905817478239
#       ],
#       [
#        -121.94377221086529,
#        39.71853999332125
#       ],
#       [
#        -121.92286947750591,
#        39.791380627941564
#       ],
#       [
#        -121.63227618846528,
#        39.741888925223755
#       ],
#       [
#        -121.63579112595993,
#        39.72978490321332
#       ],
#       [
#        -121.63491533175898,
#        39.729636113498096
#       ],
#       [
#        -121.6524265964997,
#        39.66905817478239
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20181120_182809_1008",
#    "properties": {
#     "acquired": "2018-11-20T18:28:09.486439Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0.47,
#     "columns": 8887,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.9,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "origin_x": 590529,
#     "origin_y": 4405158,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2018-11-20T22:03:15Z",
#     "quality_category": "standard",
#     "rows": 4422,
#     "satellite_id": "1008",
#     "strip_id": "1863787",
#     "sun_azimuth": 157.5,
#     "sun_elevation": 27.4,
#     "updated": "2018-11-21T04:08:20Z",
#     "usable_data": 0,
#     "view_angle": 0.1
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181120_182808_1008",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181120_182808_1008/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20181120_182808_1008/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.63438407984044,
#        39.734630200526794
#       ],
#       [
#        -121.92570511407123,
#        39.78412985972835
#       ],
#       [
#        -121.90479612348207,
#        39.85693273935952
#       ],
#       [
#        -121.6132104464217,
#        39.807248848687344
#       ],
#       [
#        -121.61823351223235,
#        39.789873424694676
#       ],
#       [
#        -121.61833669400745,
#        39.78989090192712
#       ],
#       [
#        -121.63438407984044,
#        39.734630200526794
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20181120_182808_1008",
#    "properties": {
#     "acquired": "2018-11-20T18:28:08.444154Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0.56,
#     "columns": 8907,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.9,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "origin_x": 591990,
#     "origin_y": 4412454,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2018-11-20T22:03:14Z",
#     "quality_category": "standard",
#     "rows": 4420,
#     "satellite_id": "1008",
#     "strip_id": "1863787",
#     "sun_azimuth": 157.5,
#     "sun_elevation": 27.3,
#     "updated": "2018-11-21T04:07:21Z",
#     "usable_data": 0,
#     "view_angle": 0.1
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181120_182807_1008",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181120_182807_1008/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20181120_182807_1008/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.88556942598535,
#        39.92255579456913
#       ],
#       [
#        -121.59478567039541,
#        39.87301055438422
#       ],
#       [
#        -121.61533283430656,
#        39.80030460729896
#       ],
#       [
#        -121.90724777887753,
#        39.849885831000584
#       ],
#       [
#        -121.89016758408992,
#        39.910908426257734
#       ],
#       [
#        -121.88890859499006,
#        39.91069468481009
#       ],
#       [
#        -121.88556942598535,
#        39.92255579456913
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20181120_182807_1008",
#    "properties": {
#     "acquired": "2018-11-20T18:28:07.40187Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0.56,
#     "columns": 8898,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.9,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "origin_x": 593481,
#     "origin_y": 4419759,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2018-11-20T22:03:14Z",
#     "quality_category": "standard",
#     "rows": 4417,
#     "satellite_id": "1008",
#     "strip_id": "1863787",
#     "sun_azimuth": 157.5,
#     "sun_elevation": 27.2,
#     "updated": "2018-11-21T04:07:43Z",
#     "usable_data": 0,
#     "view_angle": 0.1
#    },
#    "type": "Feature"
#   },
#   {
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181120_182806_1008",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20181120_182806_1008/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20181120_182806_1008/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "geometry": {
#     "coordinates": [
#      [
#       [
#        -121.866122109085,
#        39.988234913649315
#       ],
#       [
#        -121.57565579236251,
#        39.93877038627998
#       ],
#       [
#        -121.59620497262021,
#        39.86608545091014
#       ],
#       [
#        -121.88754042125824,
#        39.91555459420062
#       ],
#       [
#        -121.87037017416273,
#        39.97654527334941
#       ],
#       [
#        -121.86945947458659,
#        39.97639052767385
#       ],
#       [
#        -121.866122109085,
#        39.988234913649315
#       ]
#      ]
#     ],
#     "type": "Polygon"
#    },
#    "id": "20181120_182806_1008",
#    "properties": {
#     "acquired": "2018-11-20T18:28:06.359585Z",
#     "anomalous_pixels": 0,
#     "cloud_cover": 0.38,
#     "columns": 8872,
#     "epsg_code": 32610,
#     "ground_control": true,
#     "gsd": 3.9,
#     "instrument": "PS2",
#     "item_type": "PSScene4Band",
#     "origin_x": 595077,
#     "origin_y": 4427070,
#     "pixel_resolution": 3,
#     "provider": "planetscope",
#     "published": "2018-11-20T22:03:14Z",
#     "quality_category": "standard",
#     "rows": 4411,
#     "satellite_id": "1008",
#     "strip_id": "1863787",
#     "sun_azimuth": 157.6,
#     "sun_elevation": 27.2,
#     "updated": "2018-11-21T04:08:10Z",
#     "usable_data": 0,
#     "view_angle": 0.1
#    },
#    "type": "Feature"
#   }
#  ],
#  "type": "FeatureCollection"
# }

# %%
# extract image IDs only
image_ids = [feature['id'] for feature in search_result.json()['features']]
print(image_ids)
# Out:
# ['20181130_180019_1043', '20181130_180018_1043', '20181130_180017_1043', '20181130_180012_1043', '20181130_175422_100d', '20181130_175421_100d', '20181130_175420_100d', '20181130_175419_100d', '20181130_175418_100d', '20181130_175417_100d', '20181130_175416_100d', '20181130_175415_100d', '20181130_175414_100d', '20181130_175413_100d', '20181130_180016_1043', '20181130_180015_1043', '20181130_180014_1043', '20181130_180013_1043', '20181130_180011_1043', '20181130_182521_1015', '20181130_182342_1039', '20181130_182758_0f4e', '20181130_182757_0f4e', '20181130_182756_0f4e', '20181130_182753_0f4e', '20181130_182751_0f4e', '20181130_182805_100a', '20181130_182803_100a', '20181130_182802_100a', '20181130_182801_100a', '20181130_182800_100a', '20181130_182759_100a', '20181130_182758_100a', '20181130_182757_100a', '20181130_182756_100a', '20181130_175817_101c', '20181130_175816_101c', '20181130_175815_101c', '20181130_175814_101c', '20181130_175813_101c', '20181130_175812_101c', '20181130_175811_101c', '20181130_175810_101c', '20181130_175809_101c', '20181130_175808_101c', '20181130_182344_1039', '20181130_182343_1039', '20181130_182341_1039', '20181130_182340_1039', '20181130_182339_1039', '20181130_182337_1039', '20181130_182336_1039', '20181130_182755_0f4e', '20181130_182752_0f4e', '20181130_182520_1015', '20181130_182519_1015', '20181130_182518_1015', '20181130_182517_1015', '20181130_182516_1015', '20181129_182818_1003', '20181129_182817_1003', '20181128_182909_0f15', '20181128_182908_0f15', '20181128_182907_0f15', '20181128_182906_0f15', '20181128_182905_0f15', '20181128_175306_0f44', '20181128_175305_0f44', '20181128_175310_1_0f44', '20181128_175310_0f44', '20181128_175309_0f44', '20181128_175308_0f44', '20181128_175307_0f44', '20181128_182904_0f15', '20181128_182903_0f15', '20181128_182902_0f15', '20181128_181837_0e26', '20181128_175311_0f44', '20181128_182901_0f15', '20181125_180012_0f3c', '20181125_180010_0f3c', '20181125_180009_0f3c', '20181125_180008_0f3c', '20181125_180007_0f3c', '20181125_180006_0f3c', '20181125_180011_0f3c', '20181125_180009_1_0f3c', '20181125_175712_0f32', '20181125_175711_0f32', '20181125_175710_0f32', '20181125_175708_0f32', '20181125_175707_0f32', '20181125_175706_0f32', '20181125_175705_0f32', '20181125_175704_0f32', '20181125_175703_0f32', '20181125_182552_1029', '20181125_182550_1029', '20181125_182548_1029', '20181125_182546_1029', '20181125_182553_1029', '20181125_182551_1029', '20181125_182549_1029', '20181125_182547_1029', '20181125_182545_1029', '20181125_175709_0f32', '20181125_182410_1003', '20181125_182409_1003', '20181125_182408_1003', '20181125_182407_1003', '20181125_182558_1001', '20181125_182557_1001', '20181125_182556_1001', '20181125_182555_1001', '20181125_182554_1001', '20181125_182553_1001', '20181125_182551_1001', '20181125_182550_1001', '20181125_182549_1001', '20181125_182911_102c', '20181125_182910_102c', '20181125_182909_102c', '20181125_182908_102c', '20181125_182907_102c', '20181125_182906_102c', '20181124_175909_1053', '20181124_175906_1053', '20181124_175905_1053', '20181124_182715_1014', '20181124_182714_1014', '20181124_175627_1052', '20181124_175626_1052', '20181124_175625_1052', '20181124_175624_1052', '20181124_175912_1053', '20181124_175911_1_1053', '20181124_175911_1053', '20181124_175910_1053', '20181124_175908_1053', '20181124_175907_1053', '20181124_175631_1052', '20181124_175630_1052', '20181124_175629_1052', '20181124_175628_1_1052', '20181124_175628_1052', '20181124_182814_1035', '20181124_182813_1035', '20181124_182812_1035', '20181124_182811_1035', '20181124_182810_1035', '20181124_182809_1035', '20181124_182808_1035', '20181124_182807_1035', '20181124_182806_1035', '20181124_182713_1014', '20181124_182712_1014', '20181124_182711_1014', '20181124_182710_1014', '20181124_182709_1014', '20181124_182708_1014', '20181124_182707_1014', '20181122_175805_0f21', '20181122_175804_0f21', '20181122_175803_0f21', '20181122_175802_0f21', '20181122_175801_0f21', '201811 ...

# %%
# For demo purposes, just grab the first image ID
id0 = image_ids[0]
id0_url = 'https://api.planet.com/data/v1/item-types/{}/items/{}/assets'.format(item_type, id0)

# Returns JSON metadata for assets in this ID. Learn more: planet.com/docs/reference/data-api/items-assets/#asset
result = \
  requests.get(
    id0_url,
    auth=HTTPBasicAuth(PLANET_API_KEY, '')
  )

# List of asset types available for this particular satellite image
print(result.json().keys())
# Out:
# dict_keys(['analytic', 'analytic_dn', 'analytic_dn_xml', 'analytic_sr', 'analytic_xml', 'basic_analytic', 'basic_analytic_dn', 'basic_analytic_dn_nitf', 'basic_analytic_dn_rpc', 'basic_analytic_dn_rpc_nitf', 'basic_analytic_dn_xml', 'basic_analytic_dn_xml_nitf', 'basic_analytic_nitf', 'basic_analytic_rpc', 'basic_analytic_rpc_nitf', 'basic_analytic_xml', 'basic_analytic_xml_nitf', 'basic_udm', 'udm'])

# %% [markdown]
#  ## Activation and Downloading
#
# The Data API does not pre-generate assets, so they are not always immediately availiable to download. In order to download an asset, we first have to **activate** it.
#
# Remember, earlier we decided we wanted a color-corrected image best suited for *analytic* applications. We can check the status of the analytic asset we want to download like so:

# %%
# This is "inactive" if the "analytic" asset has not yet been activated; otherwise 'active'
print(result.json()['analytic']['status'])
# Out:
# active

# %%
#activate asset for download

# Parse out useful links
links = result.json()[u"analytic"]["_links"]
self_link = links["_self"]
activation_link = links["activate"]

# Request activation of the 'analytic' asset:
activate_result = \
  requests.get(
    activation_link,
    auth=HTTPBasicAuth(PLANET_API_KEY, '')
  )

# %%
activation_status_result = \
  requests.get(
    self_link,
    auth=HTTPBasicAuth(PLANET_API_KEY, '')
  )
    
print(activation_status_result.json()["status"])
# Out:
# active

# %%
# Image can be downloaded by making a GET with your Planet API key, from here:
download_link = activation_status_result.json()["location"]
print(download_link)
# Out:
# https://api.planet.com/data/v1/download?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9..U_EILaVMgHdwkhCrm2yqyWfGd7bnYViR8V7SgccIk5ifIfRsxJq5tAU1A0qLKYU_aizjXlfBIJHY6V6N6XSP8w
